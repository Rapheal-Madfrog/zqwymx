# %%
# %matplotlib qt
import numpy as np
import pandas as pd
from pandas import DataFrame
from scipy import stats
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import gc
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures,StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score,KFold
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
from sklearn.externals import joblib
from sklearn.svm import SVC
import sklearn.metrics as metrics
import xgboost as xgb
from xgboost import XGBClassifier
import warnings
from hyperopt import tpe,fmin,hp
from hpsklearn import random_forest,HyperoptEstimator
warnings.filterwarnings('ignore')

path = './data/Debt issuing company 2018 report/'
# Out:
# WARN: OMP_NUM_THREADS=None =>
# ... If you are using openblas if you are using openblas set OMP_NUM_THREADS=1 or risk subprocess calls hanging indefinitely

# %%
# 去掉异常值

def drop_out(frame,col,model='Confidence interval',t_alpha=0.95,alpha=2,IQR_rate=1.5,quantile=0.95):
    '''modle: 'gauss','box','quantile' '''
    
    if model == 'Confidence interval':
        u_ = frame[col].mean()
        v_ = frame[col].std()
        interval_ = stats.t.interval(t_alpha,frame[col].count()-1,u_,v_)
        cond_ = (frame[col]<interval_[1])&(frame[col]>interval_[0])
    
    elif model == 'gauss':
        u_ = frame[col].mean()
        v_ = frame[col].std()
        cond_ = (frame[col]-u_)/v_ < alpha
    
    elif model == 'box':
        q1 = frame[col].quantile(0.25)
        q3 = frame[col].quantile(0.75)
        IQR = (q3-q1)*IQR_rate
        q1 -= IQR ; q3 += IQR
        cond_ = (frame[col]<q3)&(frame[col]>q1)
    
    elif model == 'quantile':
        top_ = frame[col].quantile(quantile)
        bottom_ = frame[col].quantile(1-quantile)
        cond_ = (frame[col]<top_)&(frame[col]>bottom_)
    
    else:
        print('please try again')
        return frame
    
    index_ = np.where(frame[col]!=frame[col],True,
                                                  np.where(cond_,True,False))
    frame = frame.loc[index_,:]
    return frame

# 时间操作

def mms(frame,groupby,col,):
    max_ = dict(frame.groupby(by=groupby,)[col].max())
    min_ = dict(frame.groupby(by=groupby,)[col].min())
    max_ = frame[groupby].map(lambda x:max_[x])
    min_ = frame[groupby].map(lambda x:min_[x])
    result = (frame[col].values - min_)/(max_-min_)
    return [round(i,2) for i in result]

def moving(frame,groupby,time_col,col,wins=3,weight=[0.55,0.3,0.15]):
    '''wins是窗口数,weight是权重,这两个必须对应'''
    frame = frame.sort_values([groupby,time_col])
    for i in range(wins):
        if i == 0 :
            list_ = weight[i]*(frame[col].values)
        else :
            list_ += weight[i]*(frame.groupby(groupby)[col].rolling(i+1).mean().values)
    return list_

def bodonglv(frame,groupby,time_col,col,wins):
    frame = frame.sort_values([groupby,time_col])
    std_ = (frame.groupby(groupby)[col].rolling(wins).std().values)
    mean_ = (frame.groupby(groupby)[col].rolling(wins).mean().values)
    return [round(std_[i]/mean_[i],2) for i in range(len(std_))]

def tongbi(frame,groupby,time_col,col,diff):
    frame = frame.sort_values([groupby,time_col])
    diff_ = frame.groupby(groupby)[col].diff(diff).values
    ori_ = frame[col].values
    return [np.nan]*diff+[round(diff_[i]/abs(ori_[i-diff]),2) for i in range(diff,frame.shape[0])]

# 补充空白值

def diy_ss(frame,weight_dict,quantile=0.2):
    for i in frame.columns:
        if ('%' not in i) and ('/' not in i) and ('率' not in i) and ('倍数' not in i):
            if frame[i].min() >= 0:
                frame[i] = np.log1p(frame[i])
                weight_dict[i] = 'log1p'
            else :
                mean_ = frame[i][(frame[i]>=frame[i].quantile(quantile)) & (frame[i] <= frame[i].quantile(1-quantile))].mean()
                std_ = frame[i][(frame[i]>=frame[i].quantile(quantile)) & (frame[i] <= frame[i].quantile(1-quantile))].std()
                weight_dict[i] = [mean_,std_]
                frame[i] = (frame[i]-mean_)/std_
    return frame,weight_dict

def fillna_(frame,group_col,quantile=0.2,n_epoch=3):
    
    def return_index(aa,bb):
        j=0
        cc = []
        for i in range(len(aa)):
            if aa[i] == False :
                cc.append(aa[i])
            else:
                cc.append(bb[j])
                j += 1
        return cc
    
    frame_col = frame.columns
    
    for l,comp in enumerate(set(group_col)):

        index_y = list(group_col == comp)
        full_col = []
        loss_col = {}

        for col in frame.columns:
            if frame.loc[index_y,col].isnull().sum() == 0:
                full_col.append(col)
            else:
                loss_col[col] = frame.loc[index_y,col].isnull().sum()

        loss_col = sorted(loss_col.items(),key=lambda x:x[1])
        loss_col = [i[0] for i in loss_col]
        
        index_dict = {}
        if len(full_col) == 0:
            index_dict[loss_col[0]] = frame.loc[index_y,loss_col[0]].isnull()
            index_dict[loss_col[0]].fillna(index_dict[loss_col[0]].median(),inplace=True)
            full_col.append(loss_col[0])
            loss_col = loss_col[1:]
            
        for epoch in range(n_epoch):

            if epoch == 0:
                for _,col in enumerate(loss_col):
                    if np.random.rand()>0.75:
                        print(comp,f'{l}/{len(set(group_col))}',col,f'{_}/{len(loss_col)}')
                    index_l = list(frame.loc[index_y,col].isnull())
                    index_f = list(frame.loc[index_y,col].notnull())
                    index_l_ = return_index(index_y,index_l)
                    index_f_ = return_index(index_y,index_f)
                    index_dict[col] = (index_l_,index_f_)
                    rfr = RandomForestRegressor(n_estimators=10,n_jobs=-1,max_features=0.9)
                    rfr.fit(frame.loc[index_f_,full_col],frame.loc[index_f_,col])
                    pre = rfr.predict(frame.loc[index_l_,full_col])
                    frame.loc[index_l_,col] = pre
                    full_col.append(col)
            
            else:
                for col in index_dict:
                    index_l_ = index_dict[col][0]
                    index_f_ = index_dict[col][1]
                    rfr = RandomForestRegressor(n_estimators=20,n_jobs=-1,max_features=0.6)
                    rfr.fit(frame.loc[index_f_,full_col],frame.loc[index_f_,col])
                    pre = rfr.predict(frame.loc[index_l_,full_col])
                    frame.loc[index_l_,col] = pre
                    
    gc.collect()
    return frame[frame_col]

# 独热编码

def one_hot_str(frame,col,replace=True):
    if replace:
        a_ = frame.pop(col)
    else:
        a_ = frame[col]
    a_.fillna('miss',inplace=True)
    a_ = pd.get_dummies(a_,prefix=a_.name)
    frame = pd.concat([frame,a_],axis=1)
    del a_
    return frame
def one_hot_int(frame,col,number):
    a_ = frame.pop(col)
    a_ = pd.qcut(a_,number)
    col_name_ = [a_.name+'_'+str(i+1) for i in range(number)]
    a_ = pd.get_dummies(a_,)
    a_.columns = col_name_
    frame = pd.concat([frame,a_],axis=1)
    del a_,col_name_
    return frame

# 截取时间节点

def getxyb(date,delta_y = 1,):
    '''得到当前日期的前几年最后一天,默认1年'''
    aaa = date - pd.tseries.offsets.DateOffset(years=1*delta_y)
    return aaa + pd.tseries.offsets.DateOffset(years=1,months=1 - aaa.month, days= - aaa.day)
def getxsb(date,delta_s = 1,):
    '''得到当前日期的前几个季度最后一天,默认1季度'''
    aaa = date - pd.tseries.offsets.DateOffset(months=3*delta_s)
    return aaa + pd.tseries.offsets.DateOffset(months=3 - ((aaa.month - 1) % 3), days=-aaa.day)
def getxhyb(date,delta_hy = 1,):
    '''得到当前日期的前几个半年最后一天,默认1半年'''
    aaa = date - pd.tseries.offsets.DateOffset(months=6*delta_hy)
    return aaa + pd.tseries.offsets.DateOffset(months=6 - ((aaa.month - 1) % 6), days=-aaa.day)

# 原始财务数据读取+分布图

start_year = 2013
end_year = 2018
data_a = DataFrame()
for i in range(start_year, end_year+1):
    if i % 3 ==0:
        print('is concating {} {}/{}'.format(i, i-start_year+1, end_year+1-start_year))
    path_a = path+'a/{}a.xlsx'.format(i)
    data_a_ = pd.read_excel(path_a)[:-2]
    data_a_.drop(['是否经过审计','审计意见'] + [i for i in data_a_.columns if i.find('E') >= 0], axis=1, inplace=True)
    data_a_.loc[:, ['主营业务收入(亿元)', '主营业务利润(亿元)', '净利润(亿元)']] = \
    data_a_.loc[:, ['主营业务收入(亿元)', '主营业务利润(亿元)', '净利润(亿元)']].apply(lambda x:x/data_a_['报告期'].dt.month)
    data_a = pd.concat([data_a, data_a_])
del data_a_
gc.collect()
print('finish concat data_y')

print(np.array(list(data_a.isnull().sum(0))))
# data_a.dropna(thresh=data_a.shape[1]-6,inplace=True)

# for i in range(data_a.shape[1]-2):
#     ax = plt.subplot(5,5,i+1)
#     ax.scatter(range(data_a.shape[0]),data_a.iloc[:,i+2].sort_values(),s=3)
#     plt.title(data_a.columns[i+2])
# plt.suptitle('散点趋势图')

# 公司信息读取

# list_all_col = ['名称','主营业务收入(万元)','净资产(万元)', 
#                 '所属省市', '所属县市', '企业性质', '是否上市','成立日期','注册资本(万元)',
#                 '所属行业一级', '所属行业二级', '所属行业三级','所属行业四级']#'最新评级',

# all_com = pd.read_excel(path+'all_company.xlsx',)[:-2]
# all_com = all_com[list_all_col]

# all_com = all_com[['名称','所属省市','所属行业一级', '所属行业二级', '所属行业三级', '所属行业四级' ,
#        '注册资本(万元)','企业性质', '是否上市']]

indestry = pd.read_excel(path+'comp_feature/产业类发债企业行业分类0827.xlsx', sheet_name='产业类企业')
indestry.insert(1, '是否交通', 0)
transport = pd.read_excel(path+'comp_feature/产业类发债企业行业分类0827.xlsx', sheet_name='交通运输')
transport.insert(1, '是否交通', 1)
all_com = pd.concat([indestry, transport,], ignore_index=True)[['名称', '是否交通',
                                                              '最新评级', '企业性质', '是否上市','一级分类', '二级分类']]
del indestry, transport

list_company_property = ['民营企业', '地方国有企业', '中央国有企业']
all_com['企业性质'] = all_com['企业性质'].map(lambda x:x if x in list_company_property else '其他')

# 违约信息读取+筛选第一次

list_re_col = ['发生日期','名称',]#'发行时主体评级'

re_of_de = pd.read_excel(path+'report of defaulted.xlsx',)[:-2]
re_of_de = re_of_de[list_re_col]
gc.collect()
print('违约记录数:', re_of_de['名称'].shape[0])
re_of_de = re_of_de.groupby(['名称',], as_index=False).apply(lambda x:x.sort_values(['发生日期']).iloc[0])
print('违约公司数:', re_of_de['名称'].shape[0])
all_com['whetherin'] = all_com['名称'].isin(re_of_de['名称'])*1  ##  总表中的违约公司
print('总表里的违约公司数:', sum(all_com['whetherin']))
re_of_de['whetherin'] = re_of_de['名称'].isin(all_com['名称'])*1  ##   在总表中有记录的违约公司
print('缺失数:',re_of_de['名称'].shape[0]-sum(all_com['whetherin']))

loss_re_name = re_of_de.loc[re_of_de['whetherin']==0, '名称']
print('缺失的公司名如下:\n---------------------------\n', pd.unique(loss_re_name), re_of_de.shape)

re_of_de = re_of_de.loc[re_of_de['whetherin']==1,:]

re_of_de = re_of_de.iloc[:,:-1]
all_com = all_com.iloc[:,:-1]

# 时光机器-一个季度前

re_of_de['发生日期'] = re_of_de['发生日期'].map(lambda x:getxsb(x))

# 处理财报数据,如果要画图就在这里改

# data_a = data_a.loc[data_a['名称'].isin(all_com['名称']),:]

# re_of_de = re_of_de.merge(data_a, on=['名称',],)  #留下违约公司所有财报数据re_of_de
# re_of_de = re_of_de.loc[re_of_de['发生日期'] >= re_of_de['报告期'],:]
# re_of_de.insert(0, 'target', (re_of_de['发生日期'] - re_of_de['报告期']).map(lambda x:x.days))

# data_a.insert(0, 'target', -1)
# fin_col = re_of_de.columns
# data_a = data_a.loc[~data_a['名称'].isin(re_of_de['名称']), :]   #总的数据表中剔除re_of_de

# data_2018 = data_a.loc[data_a['报告期'] == '2018-06-30', :]
# data_a = data_a.loc[data_a['报告期'] != '2018-06-30', :]

# data_a.dropna(inplace=True)  #总表剔除nan

# for k in range(2):
#     col_ = np.random.choice(data_a.columns[3:-1],len(data_a.columns[3:-1]),replace=False,)
#     for j in col_:
#         data_a = drop_out(data_a, j, model='gauss', alpha=3)

# a = pd.concat([re_of_de, data_2018, data_a])[fin_col]

# del re_of_de, data_a
# gc.collect()

# weight_dict = {}
# a.iloc[:, 4:-1],weight_dict = diy_ss(a.iloc[:, 4:-1], weight_dict, 0)

# a = pd.concat([a, pd.get_dummies(a['报告期'].dt.year)], axis=1)

# com_flist = ['名称', '是否交通', '一级分类', '企业性质', '是否上市']
# a = a.merge(all_com[com_flist], on='名称')

# com_flist_ = com_flist.copy()
# for o in ['名称', '一级分类']:
#     com_flist_.remove(o)

# for i in com_flist_:
#     a = one_hot_str(a, i)

# drop_length = 1
# drop_length += len(set(a['报告期'].dt.year))
# for i in com_flist_:
#     drop_length += len(set(all_com[i]))

# cols_a = list(a)
# cols_a.insert(len(cols_a), cols_a.pop(cols_a.index('一级分类')))
# a = a[cols_a]

# a.iloc[:, 4:-1] = fillna_(a.iloc[:, 4:-1],a['一级分类'] ,n_epoch=4)

# def rechange(dataframe, col, weight):
#     if col in weight.keys() :
#         if weight[col] == 'log1p':
#             return np.exp(dataframe[col]) - 1
#         else:
#             return dataframe[col] * weight[col][1] + weight[col][0]
#     else :
#         return dataframe[col]

# a = a.iloc[:, :drop_length * -1]
# a.insert(a.shape[1],'净利润/带息债务',rechange(a,'净利润(亿元)',weight_dict)/((rechange(a,'带息债务(亿元)',weight_dict))+0.01))
# a[['净利润/带息债务']],weight_dict = diy_ss(a[['净利润/带息债务']],weight_dict,0)

# a.to_excel(path+'2013-2018_a.xlsx',index=False)
# joblib.dump(weight_dict,path+'weight_dict_a.m')

fin_col = re_of_de.columns

del re_of_de
gc.collect()

a = pd.read_excel(path+'2013-2018_a.xlsx')
weight_dict = joblib.load(path+'weight_dict_a.m')

# 违约范围划定

a.loc[a['发生日期'].notnull(),'target'] = a.loc[a['发生日期'].notnull(),'target'].map(lambda x: 1 if x <= 93 else 2)

a.drop('发生日期',axis=1,inplace=True)
re_of_de_0 = a.loc[a['target']==2,:]
re_of_de_1 = a.loc[a['target']==1,:]
data_2018 = a.loc[(a['报告期'] == '2018-06-30')&(a['target'] == -1),:]
data_a = a.loc[(a['报告期'] != '2018-06-30')&(a['target'] == -1),:]
del a
data_a = data_a.loc[data_a['报告期'].between('2016-01-01','2018-03-31')]
gc.collect()

# 处理公司非财报数据

all_com = one_hot_str(all_com,'企业性质',replace=False)
all_com = one_hot_str(all_com,'是否上市',replace=False)

re_of_de_0 = re_of_de_0.merge(all_com,on='名称',)
re_of_de_1 = re_of_de_1.merge(all_com,on='名称',)
data_2018 = data_2018.merge(all_com,on='名称',)
data_a = data_a.merge(all_com,on='名称')
del all_com

# 看看corr

# a = [('净资产回报率(%)', 0.2831613389507573),
#  ('净利润(亿元)', 0.19612521767114766),
#  ('流动比率', 0.10006272874771727),
#  ('净资产(亿元)', 0.07643978218479412),
#  ('主营业务利润(亿元)', 0.06485263851265907),
#  ('货币资金/短期债务', 0.04648683392338189),
#  ('总资产报酬率(%)', 0.03358045966497278),
#  ('筹资活动现金流(亿元)', 0.0299973498895215),
#  ('投资活动现金流(亿元)', 0.02486080556388141),
#  ('总资产(亿元)', 0.02458365655281366),
#  ('短期债务/总债务', 0.023363955568147503),
#  ('经营活动现金流(亿元)', 0.01991941294740471),
#  ('速动比率', 0.017362472591467188),
#  ('货币资产(亿元)', 0.013813465657292835),
#  ('带息债务(亿元)', 0.012756002097363587),
#  ('主营业务收入(亿元)', 0.00853891335415696),
#  ('净债务(亿元)', 0.008103904697081556),
#  ('主营业务利润率(%)', 0.005525472849658592),
#  ('资产负债率', 0.0040236587366119),
#  ('存货周转率', 0.002683313003464182),
#  ('总债务(亿元)', 0.002371458968943401),]
# pd.concat([re_of_de,data_2018,data_a])[[i[0] for i in a]].corr().to_excel(path+'corr.xlsx',)

# list_choich = ['名称', '报告期','获息倍数','货币资金/短期债务','净利润亿元','筹资活动现金流亿元','主营业务利润率%',
#                 '主营业务收入增长率%','投资活动现金流亿元','净资产回报率%','总资产报酬率%','流动比率']


# for i in [re_of_de,data_2018]:
#     i.fillna(0,inplace=True)

# 把标签特征移入data_object

object_list = ['名称', '报告期','最新评级','企业性质', '是否上市', '一级分类', '二级分类',]
data_a_object = pd.DataFrame();data_2018_object = pd.DataFrame();re_object_0 = pd.DataFrame();re_object_1 = pd.DataFrame()

for i in object_list:
    data_a_object = pd.concat([data_a_object,data_a.pop(i)],axis=1)
for i in object_list:
    data_2018_object = pd.concat([data_2018_object,data_2018.pop(i)],axis=1)
for i in object_list:
    re_object_0 = pd.concat([re_object_0,re_of_de_0.pop(i)],axis=1)
for i in object_list:
    re_object_1 = pd.concat([re_object_1,re_of_de_1.pop(i)],axis=1)

re_target_0 = re_of_de_0.pop('target')
re_target_0 = re_target_0.map(lambda x : 0)
re_target_1 = re_of_de_1.pop('target')
data_a_target = data_a.pop('target')
data_a_target = data_a_target.map(lambda x : 0)
data_2018.drop(['target'],axis=1,inplace=True)

# 数据集 -> x1,x2,y1,y2

def get_hxy(length_0=0.6,length_a=0.022,test_size=0.3,simple=False,random_state=None):
    '''横向数据'''
    global x1,x2,y1,y2,list_
    list_ = re_of_de_1.columns
    index_a = np.random.permutation(len(data_a_target))[:int(len(data_a_target)*length_a)]
    x1,x2,y1,y2 = train_test_split(pd.concat([re_of_de_1,data_a.iloc[index_a,:]],),
                                   np.r_[re_target_1,[0]*(len(index_a))],test_size=test_size,random_state=random_state)
    if simple:
        pass

def get_zxy(length_0=0.6,test_size=0.3,simple=False,random_state=None):
    '''纵向数据'''
    global x1,x2,y1,y2,list_
    list_ = re_of_de_1.columns
    index_0 = np.random.permutation(len(re_target_0))[:int(len(re_target_0)*length_0)]
    x1,x2,y1,y2 = train_test_split(pd.concat([re_of_de_1,re_of_de_0.iloc[index_0,:],],),
                                   np.r_[re_target_1,[0]*(len(index_0))],test_size=test_size,random_state=random_state)
    if simple:
        list_ = ['获息倍数','货币资金/短期债务','净利润(亿元)','筹资活动现金流(亿元)','主营业务利润率(%)',
                 '主营业务收入增长率(%)','投资活动现金流(亿元)','净资产回报率(%)','总资产报酬率(%)','流动比率',]
        x1 = x1[list_]
        x2 = x2[list_]
# Out:
# is concating 2013 1/6
# is concating 2016 4/6
# finish concat data_y
# [    0     1  3424  7725  3628  3864  9156  9156  2274  3119  2803   622
#   1357  1015  1822  8058  6564  2001  7803  8873  8349  4728  9206  9185
#   8989  7734 16029]
# 违约记录数: 181
# 违约公司数: 74
# 总表里的违约公司数: 65
# 缺失数: 9
# 缺失的公司名如下:
# ---------------------------
#  ['东兴金满堂商贸有限公司' '山东迪浩耐磨管道股份有限公司' '惠州侨兴电信工业有限公司' '惠州侨兴电讯工业有限公司'
#  '甘肃华协农业生物科技股份有限公司' '甘肃宏良皮业股份有限公司' '百花医药集团股份有限公司' '鄂尔多斯市益通路桥有限公司'
#  '陕西通海绒业股份有限公司'] (74, 3)

# %% [markdown]
# # hpsklearn

# %%
def model_score(args):
    n_estimators ,max_depth ,min_samples_split ,max_features = args
    model = RandomForestClassifier(n_estimators=n_estimators,max_depth=max_depth,
                                   class_weight='balanced',n_jobs=-1,
                                   min_samples_split=min_samples_split,max_features=max_features,)
    model.fit(x1,y1)
    pre = model.predict(x2)
    recall_ = metrics.recall_score(pre,y2)
    accu_ = metrics.accuracy_score(pre,y2)
    auc_ = metrics.roc_auc_score(pre,y2)
    score_ = -(recall_*0.7+auc_*0.15+accu_*0.15)
    return score_

space_dict = {
              'n_estimators':[i for i in range(30,121,5)],
              'max_depth':[2,3,4,5,],
              'min_samples_split':[i for i in range(2,11,2)],
              'max_features':[i/100 for i in range(50,71,5)],
              }
space = [hp.choice(i,space_dict[i]) for i in space_dict.keys()]

result_list = []
for i in range(200):
    get_hxy(simple=True,random_state=i*10+5)
    index = fmin(model_score,space,tpe.suggest,150)

    result_dict = {}
    for i in index.keys():
        result_dict[i] = space_dict[i][index[i]]
    rfc = RandomForestClassifier(n_estimators = result_dict['n_estimators'],
                                 max_depth = result_dict['max_depth'],
                                 min_samples_split = result_dict['min_samples_split'],
                                 max_features = result_dict['max_features'],
                                 class_weight = 'balanced', n_jobs = -1,)
    result_list.append((rfc,result_dict))

# %%
get_zxy(simple=True,)

# %%
for n,(i,_) in enumerate(result_list):
    get_zxy(random_state=n*10+5)
    i.fit(x1,y1)
# metrics.recall_score(y2,rfc.predict(x2))
    print(0.6*metrics.recall_score(y2,i.predict(x2))+\
          0.2*metrics.roc_auc_score(y2,i.predict(x2))+\
          0.2*metrics.accuracy_score(y2,i.predict(x2)))
# Out:
# 0.43427339290146444
# 0.42708333333333337
# 0.535
# 0.6849643493761141
# 0.4540891039960288

# %%
for j in zip(['data_a','re_of_de_0','re_of_de_1'],['data_a_target','re_target_0','re_target_1']):
    pre = [i[0].predict_proba(eval(j[0])[list_])[:,1] for i in result_list]
    pre = [sum(i)/len(result_list) for i in zip(*pre)]
    pre = [1 if i>=0.5 else 0 for i in pre]
    print(f'---{j[0]}---\n',metrics.confusion_matrix(eval(j[1]),pre),'\n-----------')
# Out:
# ---data_a---
#  [[10161   446]
#  [    0     0]]
# -----------
# ---re_of_de_0---
#  [[412  33]
#  [  0   0]]
# -----------
# ---re_of_de_1---
#  [[ 0  0]
#  [ 8 43]]
# -----------

# %%
get_zxy(simple=True)

# %%
for n,(i,_) in enumerate(result_list):
    if n == 0:
        feature_importances = pd.Series(i.feature_importances_)
    else:
        feature_importances += pd.Series(i.feature_importances_)
feature_importances = pd.DataFrame(feature_importances/feature_importances.sum(),columns=['feature_importance'],)
feature_importances['id'] = list_
feature_importances.set_index(['id'],inplace=True)
feature_importances.sort_values(by=['feature_importance'],ascending=False).iloc[:10,:]
# Out:
#               feature_importance
# id
# 获息倍数                    0.154681
# 主营业务利润率(%)              0.137175
# 净利润(亿元)                 0.135164
# 流动比率                    0.101272
# 净资产回报率(%)               0.086647
# 筹资活动现金流(亿元)             0.083815
# 货币资金/短期债务               0.080709
# 总资产报酬率(%)               0.079772
# 投资活动现金流(亿元)             0.074477
# 主营业务收入增长率(%)            0.066288

# %%
pre_2018 = [i[0].predict_proba(data_2018[list_])[:,1] for i in result_list]
pre_2018 = [sum(i)/len(result_list) for i in zip(*pre_2018)]
pre_2018_ = [1 if i>=0.5 else 0 for i in pre_2018]

sum(pre_2018_)
# Out:
# 60

# %%
# data_2018_object.insert(0,'0-1 score',pre_2018)

# %%
data_2018_object.loc[[True if i==1 else False for i in pre_2018_],:].sort_values(by=['0-1 score'],ascending=False)
# Out:
#       0-1 score                    名称        报告期 最新评级    企业性质 是否上市     一级分类  \
# 1865   0.895059        山东龙力生物科技股份有限公司 2018-06-30  AA-    民营企业    是      必需品
# 2571   0.868933            山东地矿股份有限公司 2018-06-30  AA-  地方国有企业    是     投资贸易
# 1136   0.827068          华天酒店集团股份有限公司 2018-06-30  AA-  地方国有企业    是    可选消费品
# 511    0.759319       内蒙古矿业(集团)有限责任公司 2018-06-30   AA  地方国有企业    否  原材料采掘加工
# 1704   0.737303          焦作万方铝业股份有限公司 2018-06-30   AA      其他    是  原材料采掘加工
# 1445   0.729218      上海外滩投资开发(集团)有限公司 2018-06-30  AA+  地方国有企业    否    房地产开发
# 2128   0.726486          大唐电信科技股份有限公司 2018-06-30  AA-  中央国有企业    是     高端装备
# 780    0.714669            暴风集团股份有限公司 2018-06-30   A+    民营企业    是     信息技术
# 1556   0.712252        保定天威保变电气股份有限公司 2018-06-30   A+  中央国有企业    是    传统制造业
# 2198   0.706287         哈尔滨工业投资集团有限公司 2018-06-30   AA  地方国有企业    否     投资贸易
# 2148   0.678377          河南中孚实业股份有限公司 2018-06-30   AA      其他    是  原材料采掘加工
# 2292   0.673099              平高集团有限公司 2018-06-30  AA+  中央国有企业    否    传统制造业
# 203    0.671693       天津劝业场(集团)股份有限公司 2018-06-30   A+  地方国有企业    是    可选消费品
# 2554   0.671570          现代牧业(集团)有限公司 2018-06-30   AA      其他    否      必需品
# 2439   0.664101            中弘控股股份有限公司 2018-06-30  CCC    民营企业    是    房地产开发
# 1466   0.663672          上海飞乐音响股份有限公司 2018-06-30   AA  地方国有企业    是    可选消费品
# 936    0.662494        中山达华智能科技股份有限公司 2018-06-30  AA-    民营企业    是    可选消费品
# 938    0.650413         中海阳能源集团股份有限公司 2018-06-30   A+    民营企业    是      新能源
# 2120   0.647496          中基健康产业股份有限公司 2018-06-30   CC  地方国有企业    是      必需品
# 357    0.637844          沈阳惠天热电股份有限公司 2018-06-30   AA  地方国有企业    是     公用事业
# 1256   0.628115      安徽盛运环保(集团)股份有限公司 2018-06-30   CC    民营企业    是     节能环保
# 320    0.620670        贵州长征天成控股股份有限公司 2018-06-30  AA-    民营企业    是    传统制造业
# 445    0.615904       浙江向日葵光能科技股份有限公司 2018-06-30   A+    民营企业    是      新能源
# 1637   0.612823          上海申华控股股份有限公司 2018-06-30  AA-  地方国有企业    是    可选消费品
# 732    0.612170          海马汽车集团股份有限公司 2018-06-30   A+    民营企业    是    可选消费品
# 1046   0.611563       哈尔滨物业供热集团有限责任公司 2018-06-30  AA-  地方国有企业    否     公用事业
# 2430   0.609226          苏州元禾控股股份有限公司 2018-06-30  AA+  地方国有企业    否     投资贸易
# 899    0.608341           新达通科技股份有限公司 2018-06-30  NaN    民营企业    是    传统制造业
# 172    0.596515        河南有线电视网络集团有限公司 2018-06-30  AA+  地方国有企业    否    可选消费品
# 818    0.593025          天马轴承集团股份有限公司 2018-06-30   AA    民营企业    是    传统制造业
# 543    0.591339          东阳青雨传媒股份有限公司 2018-06-30  NaN    民营企业    是    可选消费品
# 1910   0.582930          福建闽东电力股份有限公司 2018-06-30   AA  地方国有企业    是     公用事业
# 1108   0.579966          山西三维集团股份有限公司 2018-06-30   A+  地方国有企业    是    传统制造业
# 247    0.579240      北京凯文德信教育科技股份有限公司 2018-06-30  AA-  地方国有企业    是    保障类消费
# 415    0.577257       天津市天房科技发展股份有限公司 2018-06-30  NaN  地方国有企业    是     信息技术
# 368    0.569496        北京信威通信技术股份有限公司 2018-06-30   AA    民营企业    否    传统制造业
# 1849   0.566102       甘肃省敦煌种业集团股份有限公司 2018-06-30   A+  地方国有企业    是      必需品
# 252    0.560537  吉林省长白山开发建设(集团)有限责任公司 2018-06-30   AA  地方国有企业    否    可选消费品
# 486    0.551900            长春燃气股份有限公司 2018-06-30   AA  地方国有企业    是     公用事业
# 517    0.551750          雏鹰农牧集团股份有限公司 2018-06-30   AA    民营企业    是      必需品
# 81     0.545734     乐视网信息技术(北京)股份有限公司 2018-06-30   AA    民营企业    是     信息技术
# 1023   0.544471            福建众和股份有限公司 2018-06-30   A+    民营企业    是  原材料采掘加工
# 258    0.539420            兰州兰石集团有限公司 2018-06-30   AA  地方国有企业    否    传统制造业
# 744    0.539124        浙江海普顿新材料股份有限公司 2018-06-30  NaN    民营企业    是    传统制造业
# 710    0.534882         北京动力源科技股份有限公司 2018-06-30   A+    民营企业    是    传统制造业
# 207    0.534003        大连友谊(集团)股份有限公司 2018-06-30  NaN    民营企业    是    可选消费品
# 1195   0.524965        北京神州泰岳软件股份有限公司 2018-06-30   AA    民营企业    是     信息技术
# 2353   0.524557          河南平高电气股份有限公司 2018-06-30  AA+  中央国有企业    是    传统制造业
# 1015   0.521813        北京信威科技集团股份有限公司 2018-06-30   AA    民营企业    是    传统制造业
# 618    0.520705          成都天翔环境股份有限公司 2018-06-30  AA-    民营企业    是     节能环保
# 539    0.520258        江西洪都航空工业股份有限公司 2018-06-30  AA+  中央国有企业    是     交通运输
# 133    0.520034  新疆五家渠蔡家湖国有资产投资经营有限公司 2018-06-30   AA  地方国有企业    否      必需品
# 2260   0.517978           柳州两面针股份有限公司 2018-06-30  AA-  地方国有企业    是    传统制造业
# 1084   0.515438          广州毅昌科技股份有限公司 2018-06-30   A+    民营企业    是    可选消费品
# 1386   0.511890         成都市公共交通集团有限公司 2018-06-30   AA  地方国有企业    否     交通运输
# 867    0.507720     新疆塔里木农业综合开发股份有限公司 2018-06-30   A+  地方国有企业    是      必需品
# 568    0.506567          贵州水城矿业股份有限公司 2018-06-30   AA  地方国有企业    否  原材料采掘加工
# 1913   0.504949         江苏连云港港口股份有限公司 2018-06-30   AA  地方国有企业    是     交通运输
# 1154   0.503015          吉林利源精制股份有限公司 2018-06-30   AA    民营企业    是  原材料采掘加工
# 144    0.501918      上海君实生物医药科技股份有限公司 2018-06-30  NaN    民营企业    是    可选消费品
#
#       二级分类
# 1865    食品
# 2571  投资管理
# 1136  酒店餐饮
# 511     有色
# 1704    有色
# 1445   房地产
# 2128  集成电路
# 780   软件开发
# 1556    电气
# 2198  投资管理
# 2148    有色
# 2292    电气
# 203     零售
# 2554    食品
# 2439   房地产
# 1466    家电
# 936   个人电子
# 938     光伏
# 2120    农业
# 357   公用事业
# 1256    环保
# 320     电气
# 445     光伏
# 1637    零售
# 732     汽车
# 1046  公用事业
# 2430  投资管理
# 899     电子
# 172   文化传媒
# 818     机械
# 543   文化传媒
# 1910  公用事业
# 1108    化工
# 247     教育
# 415   信息技术
# 368     电子
# 1849    农业
# 252     旅游
# 486   公用事业
# 517     农业
# 81     互联网
# 1023    有色
# 258     机械
# 744     化工
# 710     电气
# 207     零售
# 1195  软件开发
# 2353    电气
# 1015    电子
# 618     环保
# 539   交通运输
# 133     农业
# 2260   日用品
# 1084  个人电子
# 1386  交通运输
# 867     农业
# 568     煤炭
# 1913  港口机场
# 1154    有色
# 144     医药

# %%
# joblib.dump(result_list,path+'../../m_save/2018-06-30_result list_a.m')
# Out:
# ['./data/Debt issuing company 2018 report/../../m_save/2018-06-30_result list_a.m']

# %%
result_list = joblib.load(path+'../../m_save/2018-06-30_result list_a.m')

# %%
name = '青海省投资'

pre_2018[439]
# Out:
# 0.25988692581181766

# %%
# pd.concat([data_2018_object,data_2018],axis=1).loc[[True if i==1 else False for i in pre_2018_],:].iloc[:,:-6]\
# .to_excel(path+'2018_re名单_60.xlsx',index=False)

# %% [markdown]
# ## hxy

# %%
def model_score(args):
    n_estimators ,max_depth ,min_samples_split ,max_features = args
    model = RandomForestClassifier(n_estimators=n_estimators,max_depth=max_depth,
                                   class_weight='balanced',n_jobs=-1,
                                   min_samples_split=min_samples_split,max_features=max_features,)
    model.fit(x1,y1)
    pre = model.predict(x2)
    recall_ = metrics.recall_score(pre,y2)
    accu_ = metrics.accuracy_score(pre,y2)
    auc_ = metrics.roc_auc_score(pre,y2)
    score_ = -(recall_*0.6+auc_*0.2+accu_*0.2)
    return score_

space_dict = {
              'n_estimators':[i for i in range(30,121,5)],
              'max_depth':[2,3,4,5,6],
              'min_samples_split':[i for i in range(2,11,2)],
              'max_features':[i/100 for i in range(50,71,5)],
              }
space = [hp.choice(i,space_dict[i]) for i in space_dict.keys()]

result_list_h = []
for i in range(20):
    get_hxy(random_state=i*10)
    index = fmin(model_score,space,tpe.suggest,400)
    if (i-1)%5 == 0:
        print(i)
    result_dict_h = {}
    for i in index.keys():
        result_dict_h[i] = space_dict[i][index[i]]
    rfc = RandomForestClassifier(n_estimators=result_dict_h['n_estimators'],
                             max_depth=result_dict_h['max_depth'],
                             min_samples_split=result_dict_h['min_samples_split'],
                             max_features=result_dict_h['max_features'],
                             class_weight='balanced',n_jobs=-1,)
    result_list_h.append((rfc,result_dict_h))
# Out:
# 1
# 6
# 11
# 16

# %%
for n,(i,_) in enumerate(result_list_h):
    get_zxy(random_state=n*10)
    i.fit(x1,y1)
# metrics.recall_score(y2,rfc.predict(x2))
    print(0.6*metrics.recall_score(y2,i.predict(x2))+\
          0.2*metrics.roc_auc_score(y2,i.predict(x2))+\
          0.2*metrics.accuracy_score(y2,i.predict(x2)))
# Out:
# 0.37761696450732196
# 0.36839430894308944
# 0.42666666666666664
# 0.5730837789661318
# 0.3044939811367585
# 0.48141025641025637
# 0.38513888888888886
# 0.5159845636819321
# 0.43333333333333335
# 0.5295470342910102
# 0.41768805993203584
# 0.35188008130081305
# 0.5249999999999999
# 0.6809567901234568
# 0.37426780838917845
# 0.37162303058387397
# 0.4889244186046512
# 0.39874331550802145
# 0.37426780838917845
# 0.41794131455399064

# %%
for j in zip(['data_a','re_of_de_0','re_of_de_1'],['data_a_target','re_target_0','re_target_1']):
    pre = [i[0].predict_proba(eval(j[0])[list_])[:,1] for i in result_list_h]
    pre = [sum(i)/len(result_list_h) for i in zip(*pre)]
    pre = [1 if i>=0.5 else 0 for i in pre]
    print(f'---{j[0]}---\n',metrics.confusion_matrix(eval(j[1]),pre),'\n-----------')
# Out:
# ---data_a---
#  [[10430   177]
#  [    0     0]]
# -----------
# ---re_of_de_0---
#  [[433  12]
#  [  0   0]]
# -----------
# ---re_of_de_1---
#  [[ 0  0]
#  [17 34]]
# -----------

# %%
for n,(i,_) in enumerate(result_list):
    if n == 0:
        feature_importances = pd.Series(i.feature_importances_)
    else:
        feature_importances += pd.Series(i.feature_importances_)
feature_importances = pd.DataFrame(feature_importances/feature_importances.sum(),columns=['feature_importance'],)
feature_importances['id'] = list(re_of_de_0)
feature_importances.set_index(['id'],inplace=True)
feature_importances.sort_values(by=['feature_importance'],ascending=False).iloc[:10,:]
# Out:
#              feature_importance
# id
# 流动比率                   0.094564
# 净资产回报率(%)              0.080026
# 经营活动现金流(亿元)            0.061908
# 短期债务/总债务               0.061157
# 获息倍数                   0.060783
# 净利润(亿元)                0.057040
# 净利润/带息债务               0.048542
# 主营业务利润率(%)             0.046480
# 主营业务利润(亿元)             0.046236
# 货币资金/短期债务              0.044832

# %%
pre_2018 = [i[0].predict_proba(data_2018[list_])[:,1] for i in result_list]
pre_2018 = [sum(i)/len(result_list) for i in zip(*pre_2018)]
pre_2018_ = [1 if i>=0.5 else 0 for i in pre_2018]

sum(pre_2018_)
# Out:
# 0

# %%
data_2018_object.loc[[True if i==1 else False for i in pre_2018_],:]
# Out:
# Empty DataFrame
# Columns: [名称, 报告期, 最新评级, 企业性质, 是否上市, 一级分类, 二级分类]
# Index: []

# %% [markdown]
# # XGBboost

# %% [markdown]
# ## 寻找参数

# %%
para_test = {'learning_rate': [i/1000 for i in range(1,10,2)],
              'max_depth':[i for i in range(3,8,2)], 
              'min_child_weight':[1,3,5],
              'gamma':[i/10 for i in range(1,50,8)],
              'subsample':[i/100 for i in range(50,80,5)],
              'colsample_bytree':[i/100 for i in range(30,60,5)],
              'reg_alpha':[0, 0.001, 0.005, 0.01, 0.05],
              'scale_pos_weight':[i for i in range(6,11,2)]}
xgb_ = xgb.XGBClassifier(objective= 'binary:logistic',eval_metric='auc',n_jobs=-1,early_stopping_rounds=30)
flod = KFold(n_splits=4)

grid = GridSearchCV(xgb_,param_grid=para_test,scoring='roc_auc',cv=flod,n_jobs=-1,iid=False, )

# %%
feature_importance_mean = pd.Series()
xgb_clone = []
def modelfit(alg,feature_importance_mean,xgb_clone,useTrainCV=True,cv_folds=4, early_stopping_rounds=50, n_epoch=5,):
    get_zxy()
    for i in range(n_epoch):
        if useTrainCV:
            xgb_param = alg.get_xgb_params()
            xgtrain = xgb.DMatrix(x1, label=y1)
            cvresult = xgb.cv(xgb_param, xgtrain, num_boost_round=alg.get_params()['n_estimators'], nfold=cv_folds,
                metrics='auc', early_stopping_rounds=early_stopping_rounds,)
            alg.set_params(n_estimators=cvresult.shape[0])
            del xgtrain
            gc.collect()

            if i == 0: #init
                param_test = [{'learning_rate': [0.001,0.004,0.007,0.01]},
                              {'max_depth':[i for i in range(3,8,2)], 'min_child_weight':[1,3,5]},
                              {'gamma':[i/10 for i in range(1,50,2)]},
                              {'subsample':[i/100 for i in range(50,80,3)],'colsample_bytree':[i/100 for i in range(30,60,3)]},
                              {'reg_alpha':[0, 0.001, 0.005, 0.01, 0.05]},
                              {'scale_pos_weight':[1,2,3,5]}]
                for i in range(len(param_test)):
                    gsearch = GridSearchCV(estimator = alg, param_grid = param_test[i], scoring='roc_auc',iid=False, cv=cv_folds)
                    gsearch.fit(x1,y1)
                    alg = gsearch.best_estimator_

            param_test_little_list = [['learning_rate'],
                                      ['max_depth','min_child_weight'],
                                      ['gamma'],
                                      ['subsample','colsample_bytree'],
                                      ['reg_alpha'],
                                      ['scale_pos_weight']]
            for little in range(len(param_test_little_list)):
                param_test_little_dict = {}
                for j in param_test_little_list[little]:
                    if little == 1:
                        param_test_little_dict[j] = [i for i in range(int(xgb1.get_xgb_params()[j])-1,int(xgb1.get_xgb_params()[j])+2)]
                    elif little == 3:
                        param_test_little_dict[j] = [i/1000. for i in np.linspace(int(1000*round(xgb1.get_xgb_params()[j],2)*0.9),
                                                                      int(1000*round(xgb1.get_xgb_params()[j],2)*1.1),
                                                                      3)]
                    else:
                        param_test_little_dict[j] = [i/1000. for i in np.linspace(int(1000*round(xgb1.get_xgb_params()[j],2)*0.9),
                                                                      int(1000*round(xgb1.get_xgb_params()[j],2)*1.1),
                                                                      5)]
                gsearch = GridSearchCV(estimator = alg, param_grid = param_test_little_dict, scoring='roc_auc',iid=False, cv=cv_folds)
                gsearch.fit(x1,y1)
                alg = gsearch.best_estimator_

    #Fit the algorithm on the data
    alg.fit(x1, y1,eval_metric='auc')

    #Print model report:
    print ("AUC Score (Train): %f" % metrics.roc_auc_score(y1, alg.predict_proba(x1)[:,1]))
    print ("AUC Score (Test): %f" % metrics.roc_auc_score(y2, alg.predict_proba(x2)[:,1]))
    print('Recall Score (Test): %f' % metrics.recall_score(y2, alg.predict(x2)))

    feature_importance_mean = feature_importance_mean.add(pd.Series(alg.get_booster().get_fscore()),fill_value=0)
    xgb_clone.append(alg)
    return (feature_importance_mean,xgb_clone)

xgb1 = XGBClassifier(
 learning_rate =0.001,
 n_estimators=1000,
 max_depth=3,
 min_child_weight=2,
 gamma=0.1,
 subsample=0.8,
 colsample_bytree=0.8,
 objective= 'binary:logistic',
)
feature_importance_mean,xgb_clone = modelfit(xgb1,feature_importance_mean,xgb_clone,useTrainCV=True)
# Out:
# AUC Score (Train): 0.500000
# AUC Score (Test): 0.500000
# Recall Score (Test): 0.000000

# %%
get_zxy()
xgb_clone
# Out:
# [XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#         colsample_bytree=0.72, gamma=0.09, learning_rate=0.0,
#         max_delta_step=0, max_depth=2, min_child_weight=1, missing=None,
#         n_estimators=1, n_jobs=1, nthread=None, objective='binary:logistic',
#         random_state=0, reg_alpha=0.0, reg_lambda=1, scale_pos_weight=0.9,
#         seed=None, silent=True, subsample=0.72)]

# %% [markdown]
# ## 训练

# %%
feature_importance_mean = pd.Series()

xgb_epoch = 200
xgb_list = []

for i in range(xgb_epoch):
    get_zxy(simple=True)
#     get_zxy(test_size=0.3,simple=True)
    print(x1.iloc[0,0])
    
    num_rounds = 1000 # 迭代次数
    
    params={
    'booster':'gbtree',
    'objective': 'binary:logistic',
    'n_estimators':np.random.choice([i for i in range(30,60)]),
    'gamma':np.random.choice([i/10 for i in range(1,10)]),  # 用于控制是否后剪枝的参数,越大越保守，一般0.1、0.2这样子。
    'max_depth':np.random.choice([3,4,5],p=[0.35,0.55,0.10]), # 构建树的深度，越大越容易过拟合
    'lambda':np.random.choice([i/10 for i in range(1,10)]),  # 控制模型复杂度的权重值的L2正则化项参数，参数越大，模型越不容易过拟合。
    'subsample':np.random.choice([i/100 for i in range(70,75)]), # 随机采样训练样本
    'colsample_bytree':np.random.choice([i/100 for i in range(35,45)]), # 生成树时进行的列采样
    'min_child_weight':np.random.choice([i for i in range(2,5)]), 
    'eta': np.random.choice([i/1000 for i in range(1,10)]),
    'eval_metric': 'auc',
    'scale_pos_weight':np.random.choice([3,4,5,6])
    }
    
    xgtrain = xgb.DMatrix(x1, label=y1)
    xgtest = xgb.DMatrix(x2,label=y2,)

    watchlist = [(xgtrain, 'train'),(xgtest, 'val')]
    model = xgb.train(params,xgtrain,num_rounds,watchlist,early_stopping_rounds=30,verbose_eval=10)
    xgb_list.append(model)
    if i == 0:
        feature_importance_mean = model.get_fscore()
    else:
        for g in model.get_fscore():
            feature_importance_mean[g] = feature_importance_mean.get(g,0) + model.get_fscore()[g]
    print ("AUC Score (Test): %f" % metrics.roc_auc_score(y2, model.predict(xgtest)))
    print('Recall Score (Test): %f' % metrics.recall_score(y2, [1 if i>=0.5 else 0 for i in model.predict(xgtest)]))
    
feature_importance_mean = pd.Series(feature_importance_mean).sort_values()/xgb_epoch
feature_importance_mean.plot(kind='barh', title='Feature Importance Score of Mean({})'.format(xgb_epoch))
plt.ylabel('Feature Importances')
# Out:
# 0.3908154267629185
# [0]	train-auc:0.733077	val-auc:0.635933
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.932465	val-auc:0.751844
# [20]	train-auc:0.936358	val-auc:0.764489
# [30]	train-auc:0.947363	val-auc:0.781349
# [40]	train-auc:0.953488	val-auc:0.779241
# [50]	train-auc:0.952658	val-auc:0.781349
# [60]	train-auc:0.952554	val-auc:0.778188
# Stopping. Best iteration:
# [35]	train-auc:0.947051	val-auc:0.786618
#
# AUC Score (Test): 0.783456
# Recall Score (Test): 0.615385
# -5.632517702343907
# [0]	train-auc:0.764137	val-auc:0.630756
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.936458	val-auc:0.839433
# [20]	train-auc:0.940675	val-auc:0.831169
# [30]	train-auc:0.945139	val-auc:0.824675
# [40]	train-auc:0.959226	val-auc:0.837662
# Stopping. Best iteration:
# [12]	train-auc:0.936706	val-auc:0.861865
#
# AUC Score (Test): 0.840614
# Recall Score (Test): 0.818182
# -9.196195442913886
# [0]	train-auc:0.748661	val-auc:0.549882
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.885119	val-auc:0.673259
# [20]	train-auc:0.908631	val-auc:0.659976
# [30]	train-auc:0.915377	val-auc:0.668831
# Stopping. Best iteration:
# [8]	train-auc:0.884921	val-auc:0.675325
#
# AUC Score (Test): 0.670012
# Recall Score (Test): 0.590909
# -1.224941237648749
# [0]	train-auc:0.775617	val-auc:0.631173
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.872465	val-auc:0.729167
# [20]	train-auc:0.881766	val-auc:0.690329
# [30]	train-auc:0.898161	val-auc:0.676955
# [40]	train-auc:0.905307	val-auc:0.675926
# Stopping. Best iteration:
# [14]	train-auc:0.868366	val-auc:0.73071
#
# AUC Score (Test): 0.679527
# Recall Score (Test): 0.333333
# -0.6026482647312369
# [0]	train-auc:0.747921	val-auc:0.716944
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.938134	val-auc:0.794167
# [20]	train-auc:0.953753	val-auc:0.772222
# [30]	train-auc:0.959229	val-auc:0.780556
# Stopping. Best iteration:
# [7]	train-auc:0.943408	val-auc:0.806389
#
# AUC Score (Test): 0.774444
# Recall Score (Test): 0.750000
# -1.239200417906334
# [0]	train-auc:0.820997	val-auc:0.709096
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.906302	val-auc:0.760989
# [20]	train-auc:0.922156	val-auc:0.76801
# [30]	train-auc:0.92569	val-auc:0.769231
# [40]	train-auc:0.933052	val-auc:0.781441
# [50]	train-auc:0.937567	val-auc:0.76801
# [60]	train-auc:0.939531	val-auc:0.765568
# Stopping. Best iteration:
# [36]	train-auc:0.931972	val-auc:0.787546
#
# AUC Score (Test): 0.768010
# Recall Score (Test): 0.666667
# -5.632517702343907
# [0]	train-auc:0.826835	val-auc:0.739079
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.96121	val-auc:0.805785
# [20]	train-auc:0.975893	val-auc:0.809327
# [30]	train-auc:0.977877	val-auc:0.79575
# Stopping. Best iteration:
# [2]	train-auc:0.901786	val-auc:0.819067
#
# AUC Score (Test): 0.793979
# Recall Score (Test): 0.636364
# -1.028079420659709
# [0]	train-auc:0.799653	val-auc:0.716942
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.93244	val-auc:0.708383
# [20]	train-auc:0.937599	val-auc:0.753247
# [30]	train-auc:0.9438	val-auc:0.760921
# [40]	train-auc:0.943998	val-auc:0.757379
# [50]	train-auc:0.946925	val-auc:0.763873
# [60]	train-auc:0.948512	val-auc:0.768595
# [70]	train-auc:0.944444	val-auc:0.769776
# [80]	train-auc:0.941567	val-auc:0.77863
# [90]	train-auc:0.944048	val-auc:0.770366
# [100]	train-auc:0.943353	val-auc:0.769185
# [110]	train-auc:0.943254	val-auc:0.766234
# Stopping. Best iteration:
# [80]	train-auc:0.941567	val-auc:0.77863
#
# AUC Score (Test): 0.766234
# Recall Score (Test): 0.818182
# 0.3840582779095111
# [0]	train-auc:0.848122	val-auc:0.624288
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.931428	val-auc:0.682638
# [20]	train-auc:0.938296	val-auc:0.655598
# [30]	train-auc:0.942727	val-auc:0.661765
# Stopping. Best iteration:
# [7]	train-auc:0.928825	val-auc:0.700901
#
# AUC Score (Test): 0.666509
# Recall Score (Test): 0.451613
# -0.5829056847820607
# [0]	train-auc:0.800964	val-auc:0.541892
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.967067	val-auc:0.701351
# [20]	train-auc:0.967272	val-auc:0.692973
# [30]	train-auc:0.974659	val-auc:0.691351
# [40]	train-auc:0.976813	val-auc:0.685946
# Stopping. Best iteration:
# [14]	train-auc:0.971068	val-auc:0.709189
#
# AUC Score (Test): 0.688108
# Recall Score (Test): 0.600000
# -1.239998506353587
# [0]	train-auc:0.775051	val-auc:0.618889
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.895639	val-auc:0.705556
# [20]	train-auc:0.904057	val-auc:0.748611
# [30]	train-auc:0.91501	val-auc:0.766944
# [40]	train-auc:0.919067	val-auc:0.767778
# [50]	train-auc:0.921704	val-auc:0.764444
# [60]	train-auc:0.926166	val-auc:0.777778
# [70]	train-auc:0.927789	val-auc:0.783333
# [80]	train-auc:0.926166	val-auc:0.788889
# [90]	train-auc:0.926268	val-auc:0.786111
# [100]	train-auc:0.928296	val-auc:0.788333
# [110]	train-auc:0.929513	val-auc:0.791111
# Stopping. Best iteration:
# [82]	train-auc:0.926166	val-auc:0.793333
#
# AUC Score (Test): 0.790000
# Recall Score (Test): 0.791667
# -0.9345434546416731
# [0]	train-auc:0.821461	val-auc:0.690765
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.964551	val-auc:0.82556
# [20]	train-auc:0.963146	val-auc:0.816698
# [30]	train-auc:0.97236	val-auc:0.821362
# [40]	train-auc:0.972697	val-auc:0.811567
# Stopping. Best iteration:
# [12]	train-auc:0.963652	val-auc:0.826026
#
# AUC Score (Test): 0.810634
# Recall Score (Test): 0.656250
# -1.282829253022823
# [0]	train-auc:0.756865	val-auc:0.687877
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.901181	val-auc:0.736167
# [20]	train-auc:0.90943	val-auc:0.753773
# [30]	train-auc:0.922627	val-auc:0.79326
# [40]	train-auc:0.920498	val-auc:0.805835
# [50]	train-auc:0.91241	val-auc:0.800805
# [60]	train-auc:0.915496	val-auc:0.803823
# [70]	train-auc:0.916241	val-auc:0.817907
# [80]	train-auc:0.913155	val-auc:0.812877
# [90]	train-auc:0.918157	val-auc:0.820423
# Stopping. Best iteration:
# [67]	train-auc:0.915922	val-auc:0.822938
#
# AUC Score (Test): 0.815392
# Recall Score (Test): 0.607143
# -2.424840615145191
# [0]	train-auc:0.782651	val-auc:0.611351
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.908279	val-auc:0.723243
# [20]	train-auc:0.912178	val-auc:0.742703
# [30]	train-auc:0.916282	val-auc:0.762162
# [40]	train-auc:0.921925	val-auc:0.770811
# [50]	train-auc:0.9249	val-auc:0.775676
# [60]	train-auc:0.927157	val-auc:0.776216
# [70]	train-auc:0.92449	val-auc:0.785946
# [80]	train-auc:0.924284	val-auc:0.779459
# [90]	train-auc:0.923156	val-auc:0.774595
# [100]	train-auc:0.923464	val-auc:0.771351
# Stopping. Best iteration:
# [70]	train-auc:0.92449	val-auc:0.785946
#
# AUC Score (Test): 0.771351
# Recall Score (Test): 0.760000
# -2.872248998675147
# [0]	train-auc:0.795385	val-auc:0.568333
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.909939	val-auc:0.75
# [20]	train-auc:0.919168	val-auc:0.736667
# [30]	train-auc:0.931744	val-auc:0.727778
# [40]	train-auc:0.941075	val-auc:0.735
# Stopping. Best iteration:
# [11]	train-auc:0.917444	val-auc:0.763333
# AUC Score (Test): 0.735000
# Recall Score (Test): 0.708333
# 2.43354941045487
# [0]	train-auc:0.807309	val-auc:0.702055
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.932153	val-auc:0.731296
# [20]	train-auc:0.940718	val-auc:0.747629
# [30]	train-auc:0.946117	val-auc:0.743414
# [40]	train-auc:0.955669	val-auc:0.752371
# [50]	train-auc:0.958368	val-auc:0.762908
# [60]	train-auc:0.95951	val-auc:0.765016
# [70]	train-auc:0.96169	val-auc:0.765543
# [80]	train-auc:0.962313	val-auc:0.763435
# [90]	train-auc:0.964805	val-auc:0.75922
# [100]	train-auc:0.965116	val-auc:0.756059
# [110]	train-auc:0.967919	val-auc:0.751317
# Stopping. Best iteration:
# [84]	train-auc:0.96169	val-auc:0.768177
#
# AUC Score (Test): 0.749737
# Recall Score (Test): 0.576923
# -1.253459598163918
# [0]	train-auc:0.773747	val-auc:0.543596
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.948571	val-auc:0.741872
# [20]	train-auc:0.949757	val-auc:0.757635
# [30]	train-auc:0.952884	val-auc:0.747291
# [40]	train-auc:0.955148	val-auc:0.743842
# Stopping. Best iteration:
# [19]	train-auc:0.950297	val-auc:0.761576
#
# AUC Score (Test): 0.739409
# Recall Score (Test): 0.586207
# -0.9722132293520084
# [0]	train-auc:0.845132	val-auc:0.601622
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.938032	val-auc:0.664865
# [20]	train-auc:0.938853	val-auc:0.681081
# [30]	train-auc:0.935775	val-auc:0.709189
# [40]	train-auc:0.944393	val-auc:0.704324
# [50]	train-auc:0.947984	val-auc:0.708649
# Stopping. Best iteration:
# [25]	train-auc:0.933108	val-auc:0.712973
#
# AUC Score (Test): 0.705405
# Recall Score (Test): 0.680000
# -0.9554533719596982
# [0]	train-auc:0.767882	val-auc:0.538462
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.919502	val-auc:0.734389
# [20]	train-auc:0.93831	val-auc:0.737557
# [30]	train-auc:0.936806	val-auc:0.735294
# Stopping. Best iteration:
# [3]	train-auc:0.877778	val-auc:0.759276
#
# AUC Score (Test): 0.735294
# Recall Score (Test): 0.647059
# -1.021215860013334
# [0]	train-auc:0.8143	val-auc:0.548611
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.943864	val-auc:0.678889
# [20]	train-auc:0.943813	val-auc:0.748889
# [30]	train-auc:0.955172	val-auc:0.715556
# [40]	train-auc:0.958012	val-auc:0.736667
# [50]	train-auc:0.959939	val-auc:0.743333
# Stopping. Best iteration:
# [20]	train-auc:0.943813	val-auc:0.748889
#
# AUC Score (Test): 0.743333
# Recall Score (Test): 0.416667
# 138.2680243610804
# [0]	train-auc:0.790492	val-auc:0.580664
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.957677	val-auc:0.695938
# [20]	train-auc:0.960686	val-auc:0.69365
# [30]	train-auc:0.96219	val-auc:0.675629
# [40]	train-auc:0.963795	val-auc:0.688215
# Stopping. Best iteration:
# [17]	train-auc:0.962792	val-auc:0.71024
#
# AUC Score (Test): 0.689359
# Recall Score (Test): 0.565217
# -1.226111767371387
# [0]	train-auc:0.766762	val-auc:0.552198
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.900854	val-auc:0.684066
# [20]	train-auc:0.916806	val-auc:0.716117
# [30]	train-auc:0.923235	val-auc:0.691697
# [40]	train-auc:0.927358	val-auc:0.703297
# Stopping. Best iteration:
# [16]	train-auc:0.911898	val-auc:0.728632
#
# AUC Score (Test): 0.694750
# Recall Score (Test): 0.428571
# -0.1264522988499052
# [0]	train-auc:0.793301	val-auc:0.645023
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.919366	val-auc:0.718535
# [20]	train-auc:0.946445	val-auc:0.729977
# [30]	train-auc:0.953264	val-auc:0.720824
# [40]	train-auc:0.967205	val-auc:0.73341
# [50]	train-auc:0.962892	val-auc:0.741991
# [60]	train-auc:0.964998	val-auc:0.745995
# [70]	train-auc:0.965801	val-auc:0.749428
# Stopping. Best iteration:
# [43]	train-auc:0.963093	val-auc:0.756293
#
# AUC Score (Test): 0.749428
# Recall Score (Test): 0.652174
# -0.919805421315737
# [0]	train-auc:0.831589	val-auc:0.69973
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.955679	val-auc:0.839459
# [20]	train-auc:0.963271	val-auc:0.833513
# [30]	train-auc:0.965733	val-auc:0.80973
# [40]	train-auc:0.971581	val-auc:0.814054
# Stopping. Best iteration:
# [16]	train-auc:0.960808	val-auc:0.856216
#
# AUC Score (Test): 0.822162
# Recall Score (Test): 0.560000
# -1.189772140073139
# [0]	train-auc:0.798276	val-auc:0.775278
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.961055	val-auc:0.833333
# [20]	train-auc:0.954361	val-auc:0.838333
# [30]	train-auc:0.96217	val-auc:0.802778
# [40]	train-auc:0.964199	val-auc:0.807778
# Stopping. Best iteration:
# [15]	train-auc:0.961562	val-auc:0.847778
#
# AUC Score (Test): 0.807778
# Recall Score (Test): 0.666667
# -0.9458231046961803
# [0]	train-auc:0.794782	val-auc:0.661053
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.943835	val-auc:0.785104
# [20]	train-auc:0.951645	val-auc:0.757116
# [30]	train-auc:0.954359	val-auc:0.750474
# Stopping. Best iteration:
# [6]	train-auc:0.937299	val-auc:0.801708
#
# AUC Score (Test): 0.762334
# Recall Score (Test): 0.677419
# -1.121615386677745
# [0]	train-auc:0.801073	val-auc:0.612128
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.873834	val-auc:0.683066
# [20]	train-auc:0.890282	val-auc:0.732265
# [30]	train-auc:0.907231	val-auc:0.76087
# [40]	train-auc:0.911142	val-auc:0.770595
# [50]	train-auc:0.914352	val-auc:0.76373
# [60]	train-auc:0.917762	val-auc:0.764874
# [70]	train-auc:0.916859	val-auc:0.766018
# Stopping. Best iteration:
# [45]	train-auc:0.911243	val-auc:0.779176
#
# AUC Score (Test): 0.768879
# Recall Score (Test): 0.565217
# -0.6700569432220734
# [0]	train-auc:0.760052	val-auc:0.683092
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.94422	val-auc:0.709179
# [20]	train-auc:0.943837	val-auc:0.70628
# [30]	train-auc:0.959572	val-auc:0.720773
# [40]	train-auc:0.960774	val-auc:0.716908
# [50]	train-auc:0.95837	val-auc:0.717874
# Stopping. Best iteration:
# [27]	train-auc:0.957277	val-auc:0.729469
#
# AUC Score (Test): 0.720290
# Recall Score (Test): 0.600000
# -1.081444934832684
# [0]	train-auc:0.824803	val-auc:0.606164
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.928364	val-auc:0.673867
# [20]	train-auc:0.932309	val-auc:0.678609
# [30]	train-auc:0.936877	val-auc:0.657007
# [40]	train-auc:0.942795	val-auc:0.677555
# Stopping. Best iteration:
# [12]	train-auc:0.931894	val-auc:0.698894
#
# AUC Score (Test): 0.680717
# Recall Score (Test): 0.423077
# 0.3840582779095111
# [0]	train-auc:0.825434	val-auc:0.605967
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.967525	val-auc:0.679012
# [20]	train-auc:0.964372	val-auc:0.662551
# [30]	train-auc:0.968366	val-auc:0.667695
# Stopping. Best iteration:
# [6]	train-auc:0.951813	val-auc:0.698817
#
# AUC Score (Test): 0.668210
# Recall Score (Test): 0.629630
# -4.023464980889163
# [0]	train-auc:0.820881	val-auc:0.663616
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.933006	val-auc:0.756579
# [20]	train-auc:0.94494	val-auc:0.724828
# [30]	train-auc:0.945642	val-auc:0.731121
# Stopping. Best iteration:
# [9]	train-auc:0.934309	val-auc:0.764302
#
# AUC Score (Test): 0.730549
# Recall Score (Test): 0.521739
# 0.3185086134418092
# [0]	train-auc:0.792401	val-auc:0.736954
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.94162	val-auc:0.752609
# [20]	train-auc:0.952254	val-auc:0.731025
# [30]	train-auc:0.95591	val-auc:0.744307
# Stopping. Best iteration:
# [9]	train-auc:0.939016	val-auc:0.758302
#
# AUC Score (Test): 0.744307
# Recall Score (Test): 0.580645
# 1.413432757176257
# [0]	train-auc:0.745306	val-auc:0.685946
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.88894	val-auc:0.703514
# [20]	train-auc:0.903355	val-auc:0.688649
# [30]	train-auc:0.907254	val-auc:0.71027
# Stopping. Best iteration:
# [7]	train-auc:0.877603	val-auc:0.735676
#
# AUC Score (Test): 0.701081
# Recall Score (Test): 0.520000
# -0.8614385528733106
# [0]	train-auc:0.829691	val-auc:0.653784
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.940905	val-auc:0.732973
# [20]	train-auc:0.957833	val-auc:0.732432
# [30]	train-auc:0.96245	val-auc:0.742703
# [40]	train-auc:0.965528	val-auc:0.743243
# Stopping. Best iteration:
# [13]	train-auc:0.947163	val-auc:0.757297
#
# AUC Score (Test): 0.743784
# Recall Score (Test): 0.560000
# -1.48416036531648
# [0]	train-auc:0.822581	val-auc:0.626582
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.945492	val-auc:0.756962
# [20]	train-auc:0.944131	val-auc:0.751899
# [30]	train-auc:0.957151	val-auc:0.749367
# Stopping. Best iteration:
# [4]	train-auc:0.9435	val-auc:0.766139
#
# AUC Score (Test): 0.751899
# Recall Score (Test): 0.550000
# -2.094431997982504
# [0]	train-auc:0.843357	val-auc:0.661944
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.916176	val-auc:0.655556
# [20]	train-auc:0.922464	val-auc:0.658333
# [30]	train-auc:0.935548	val-auc:0.683333
# [40]	train-auc:0.93925	val-auc:0.671667
# [50]	train-auc:0.941379	val-auc:0.667222
# [60]	train-auc:0.943408	val-auc:0.659444
# Stopping. Best iteration:
# [30]	train-auc:0.935548	val-auc:0.683333
#
# AUC Score (Test): 0.659444
# Recall Score (Test): 0.583333
# 3.758908291859461
# [0]	train-auc:0.773264	val-auc:0.641622
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.897302	val-auc:0.672432
# [20]	train-auc:0.914435	val-auc:0.652973
# [30]	train-auc:0.921617	val-auc:0.632973
# Stopping. Best iteration:
# [5]	train-auc:0.869037	val-auc:0.714865
#
# AUC Score (Test): 0.620541
# Recall Score (Test): 0.560000
# 0.2974390784343335
# [0]	train-auc:0.782961	val-auc:0.701111
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.915568	val-auc:0.771389
# [20]	train-auc:0.921602	val-auc:0.770833
# [30]	train-auc:0.931339	val-auc:0.759167
# Stopping. Best iteration:
# [6]	train-auc:0.912982	val-auc:0.790556
#
# AUC Score (Test): 0.764167
# Recall Score (Test): 0.708333
# -1.220844383619518
# [0]	train-auc:0.78855	val-auc:0.558919
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.898687	val-auc:0.625946
# [20]	train-auc:0.90987	val-auc:0.645405
# [30]	train-auc:0.912691	val-auc:0.674054
# [40]	train-auc:0.912486	val-auc:0.685946
# [50]	train-auc:0.916385	val-auc:0.690811
# [60]	train-auc:0.925413	val-auc:0.691351
# [70]	train-auc:0.925516	val-auc:0.693514
# [80]	train-auc:0.925823	val-auc:0.7
# [90]	train-auc:0.927567	val-auc:0.698378
# [100]	train-auc:0.931158	val-auc:0.701622
# [110]	train-auc:0.932389	val-auc:0.707568
# [120]	train-auc:0.93516	val-auc:0.706486
# [130]	train-auc:0.937211	val-auc:0.70973
# [140]	train-auc:0.938237	val-auc:0.711351
# [150]	train-auc:0.939263	val-auc:0.713513
# [160]	train-auc:0.941315	val-auc:0.712973
# [170]	train-auc:0.943059	val-auc:0.709189
# Stopping. Best iteration:
# [147]	train-auc:0.939571	val-auc:0.715135
#
# AUC Score (Test): 0.709189
# Recall Score (Test): 0.720000
# -1.897676592786431
# [0]	train-auc:0.781198	val-auc:0.674131
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.877076	val-auc:0.72471
# [20]	train-auc:0.898983	val-auc:0.749737
# [30]	train-auc:0.90625	val-auc:0.733404
# [40]	train-auc:0.906873	val-auc:0.731296
# Stopping. Best iteration:
# [19]	train-auc:0.897425	val-auc:0.755005
#
# AUC Score (Test): 0.738145
# Recall Score (Test): 0.730769
# -0.655691351171522
# [0]	train-auc:0.818574	val-auc:0.568364
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.907482	val-auc:0.685355
# [20]	train-auc:0.919567	val-auc:0.708238
# [30]	train-auc:0.921673	val-auc:0.69651
# [40]	train-auc:0.923879	val-auc:0.685641
# Stopping. Best iteration:
# [16]	train-auc:0.913148	val-auc:0.728261
#
# AUC Score (Test): 0.694222
# Recall Score (Test): 0.478261
# -0.2902732541226766
# [0]	train-auc:0.867709	val-auc:0.656897
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.954987	val-auc:0.722414
# [20]	train-auc:0.96027	val-auc:0.700493
# [30]	train-auc:0.966146	val-auc:0.662562
# Stopping. Best iteration:
# [6]	train-auc:0.941995	val-auc:0.768473
#
# AUC Score (Test): 0.667980
# Recall Score (Test): 0.551724
# 1.781670766738729
# [0]	train-auc:0.836968	val-auc:0.596111
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.957201	val-auc:0.721667
# [20]	train-auc:0.957809	val-auc:0.700556
# [30]	train-auc:0.963793	val-auc:0.686111
# [40]	train-auc:0.968864	val-auc:0.696667
# Stopping. Best iteration:
# [10]	train-auc:0.957201	val-auc:0.721667
#
# AUC Score (Test): 0.696667
# Recall Score (Test): 0.583333
# -0.8825080878807863
# [0]	train-auc:0.760962	val-auc:0.662928
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.886706	val-auc:0.754132
# [20]	train-auc:0.887302	val-auc:0.736127
# [30]	train-auc:0.893353	val-auc:0.739669
# Stopping. Best iteration:
# [8]	train-auc:0.887599	val-auc:0.779221
#
# AUC Score (Test): 0.742031
# Recall Score (Test): 0.636364
# -0.5606656200519473
# [0]	train-auc:0.815225	val-auc:0.666487
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.949933	val-auc:0.723243
# [20]	train-auc:0.951472	val-auc:0.737297
# [30]	train-auc:0.957936	val-auc:0.743784
# [40]	train-auc:0.958551	val-auc:0.74
# [50]	train-auc:0.959372	val-auc:0.741622
# [60]	train-auc:0.96522	val-auc:0.741081
# [70]	train-auc:0.969734	val-auc:0.739459
# Stopping. Best iteration:
# [45]	train-auc:0.959988	val-auc:0.747027
#
# AUC Score (Test): 0.734595
# Recall Score (Test): 0.600000
# -0.8614385528733106
# [0]	train-auc:0.748702	val-auc:0.639094
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.875467	val-auc:0.749473
# [20]	train-auc:0.894622	val-auc:0.766596
# [30]	train-auc:0.901267	val-auc:0.755532
# [40]	train-auc:0.902616	val-auc:0.773973
# [50]	train-auc:0.906458	val-auc:0.785564
# [60]	train-auc:0.91061	val-auc:0.783456
# [70]	train-auc:0.91414	val-auc:0.786618
# [80]	train-auc:0.913829	val-auc:0.782403
# [90]	train-auc:0.915698	val-auc:0.781876
# [100]	train-auc:0.920162	val-auc:0.781876
# Stopping. Best iteration:
# [75]	train-auc:0.915075	val-auc:0.789779
#
# AUC Score (Test): 0.783456
# Recall Score (Test): 0.500000
# -0.8198315418231946
# [0]	train-auc:0.792013	val-auc:0.692387
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.936679	val-auc:0.78858
# [20]	train-auc:0.924593	val-auc:0.774691
# [30]	train-auc:0.932948	val-auc:0.758745
# Stopping. Best iteration:
# [7]	train-auc:0.941146	val-auc:0.809156
#
# AUC Score (Test): 0.775720
# Recall Score (Test): 0.740741
# 0.859718992472219
# [0]	train-auc:0.73161	val-auc:0.598378
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.886888	val-auc:0.724865
# [20]	train-auc:0.888684	val-auc:0.728108
# [30]	train-auc:0.902842	val-auc:0.734865
# [40]	train-auc:0.910126	val-auc:0.752703
# Stopping. Best iteration:
# [12]	train-auc:0.895352	val-auc:0.769189
#
# AUC Score (Test): 0.758919
# Recall Score (Test): 0.720000
# -1.224941237648749
# [0]	train-auc:0.805959	val-auc:0.753161
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.952243	val-auc:0.775026
# [20]	train-auc:0.95463	val-auc:0.808219
# [30]	train-auc:0.966881	val-auc:0.825079
# [40]	train-auc:0.972384	val-auc:0.832455
# [50]	train-auc:0.975187	val-auc:0.82824
# [60]	train-auc:0.977886	val-auc:0.82666
# [70]	train-auc:0.977367	val-auc:0.832982
# Stopping. Best iteration:
# [44]	train-auc:0.971553	val-auc:0.835616
#
# AUC Score (Test): 0.832455
# Recall Score (Test): 0.730769
# -0.7721058526774732
# [0]	train-auc:0.780917	val-auc:0.64336
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.93295	val-auc:0.728873
# [20]	train-auc:0.92848	val-auc:0.71831
# [30]	train-auc:0.928374	val-auc:0.715292
# [40]	train-auc:0.938165	val-auc:0.700704
# Stopping. Best iteration:
# [11]	train-auc:0.930928	val-auc:0.734909
#
# AUC Score (Test): 0.698692
# Recall Score (Test): 0.714286
# -0.3251763222158687
# [0]	train-auc:0.815873	val-auc:0.582054
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.949702	val-auc:0.704841
# [20]	train-auc:0.953571	val-auc:0.716057
# [30]	train-auc:0.954365	val-auc:0.695986
# [40]	train-auc:0.955853	val-auc:0.693034
# Stopping. Best iteration:
# [15]	train-auc:0.949206	val-auc:0.729044
#
# AUC Score (Test): 0.701299
# Recall Score (Test): 0.500000
# -9.196195442913886
# [0]	train-auc:0.794598	val-auc:0.668354
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.937233	val-auc:0.73038
# [20]	train-auc:0.943937	val-auc:0.729747
# [30]	train-auc:0.946463	val-auc:0.720253
# Stopping. Best iteration:
# [4]	train-auc:0.91095	val-auc:0.757595
#
# AUC Score (Test): 0.720253
# Recall Score (Test): 0.600000
# -0.5163983141776552
# [0]	train-auc:0.822811	val-auc:0.6875
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.964272	val-auc:0.774096
# [20]	train-auc:0.965021	val-auc:0.792169
# [30]	train-auc:0.971287	val-auc:0.739458
# Stopping. Best iteration:
# [8]	train-auc:0.964132	val-auc:0.803087
#
# AUC Score (Test): 0.745482
# Recall Score (Test): 0.687500
# -0.1079366468736387
# [0]	train-auc:0.816919	val-auc:0.727689
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.923829	val-auc:0.701373
# [20]	train-auc:0.931501	val-auc:0.713959
# [30]	train-auc:0.946946	val-auc:0.713959
# Stopping. Best iteration:
# [3]	train-auc:0.890382	val-auc:0.730263
#
# AUC Score (Test): 0.699085
# Recall Score (Test): 0.652174
# -0.921241980520792
# [0]	train-auc:0.802309	val-auc:0.709211
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.925445	val-auc:0.751974
# [20]	train-auc:0.928908	val-auc:0.735526
# [30]	train-auc:0.93747	val-auc:0.746711
# Stopping. Best iteration:
# [6]	train-auc:0.922078	val-auc:0.777632
#
# AUC Score (Test): 0.758553
# Recall Score (Test): 0.789474
# -0.1590143074978221
# [0]	train-auc:0.832633	val-auc:0.646862
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.947084	val-auc:0.716564
# [20]	train-auc:0.955544	val-auc:0.744342
# [30]	train-auc:0.957856	val-auc:0.757716
# [40]	train-auc:0.959012	val-auc:0.739198
# [50]	train-auc:0.958381	val-auc:0.743313
# Stopping. Best iteration:
# [23]	train-auc:0.955018	val-auc:0.764403
#
# AUC Score (Test): 0.743313
# Recall Score (Test): 0.518519
# 4.194504966370075
# [0]	train-auc:0.781796	val-auc:0.623672
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.946825	val-auc:0.752066
# [20]	train-auc:0.953274	val-auc:0.717828
# [30]	train-auc:0.950595	val-auc:0.747344
# Stopping. Best iteration:
# [9]	train-auc:0.950992	val-auc:0.760331
#
# AUC Score (Test): 0.721370
# Recall Score (Test): 0.409091
# 5.43521326646938
# [0]	train-auc:0.814176	val-auc:0.634306
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.930183	val-auc:0.685111
# [20]	train-auc:0.93891	val-auc:0.753521
# [30]	train-auc:0.957854	val-auc:0.754024
# [40]	train-auc:0.966475	val-auc:0.763078
# [50]	train-auc:0.964027	val-auc:0.763078
# [60]	train-auc:0.966049	val-auc:0.769115
# [70]	train-auc:0.968817	val-auc:0.770624
# [80]	train-auc:0.9702	val-auc:0.779678
# [90]	train-auc:0.973287	val-auc:0.781187
# [100]	train-auc:0.974777	val-auc:0.777163
# [110]	train-auc:0.976692	val-auc:0.769618
# Stopping. Best iteration:
# [86]	train-auc:0.972754	val-auc:0.785211
#
# AUC Score (Test): 0.774648
# Recall Score (Test): 0.750000
# -6.740051643544949
# [0]	train-auc:0.777183	val-auc:0.650826
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.921478	val-auc:0.728749
# [20]	train-auc:0.925992	val-auc:0.710449
# [30]	train-auc:0.921528	val-auc:0.695396
# Stopping. Best iteration:
# [6]	train-auc:0.909077	val-auc:0.74144
#
# AUC Score (Test): 0.707792
# Recall Score (Test): 0.818182
# -0.8614385528733106
# [0]	train-auc:0.832854	val-auc:0.673541
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.960622	val-auc:0.636821
# [20]	train-auc:0.958599	val-auc:0.647384
# [30]	train-auc:0.969029	val-auc:0.615694
# Stopping. Best iteration:
# [0]	train-auc:0.832854	val-auc:0.673541
#
# AUC Score (Test): 0.615694
# Recall Score (Test): 0.392857
# -1.690812067258489
# [0]	train-auc:0.763337	val-auc:0.716667
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.900963	val-auc:0.803889
# [20]	train-auc:0.912677	val-auc:0.832222
# [30]	train-auc:0.917241	val-auc:0.795
# [40]	train-auc:0.922414	val-auc:0.798333
# [50]	train-auc:0.919067	val-auc:0.797222
# Stopping. Best iteration:
# [20]	train-auc:0.912677	val-auc:0.832222
#
# AUC Score (Test): 0.797222
# Recall Score (Test): 0.625000
# -1.040636012229821
# [0]	train-auc:0.810147	val-auc:0.561351
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.914794	val-auc:0.744865
# [20]	train-auc:0.915974	val-auc:0.77027
# [30]	train-auc:0.918334	val-auc:0.765405
# [40]	train-auc:0.924387	val-auc:0.775676
# [50]	train-auc:0.92449	val-auc:0.774054
# [60]	train-auc:0.925208	val-auc:0.772432
# [70]	train-auc:0.924797	val-auc:0.76973
# Stopping. Best iteration:
# [45]	train-auc:0.92449	val-auc:0.787027
#
# AUC Score (Test): 0.763243
# Recall Score (Test): 0.600000
# -1.939656045111932
# [0]	train-auc:0.827299	val-auc:0.65389
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.96896	val-auc:0.759439
# [20]	train-auc:0.972821	val-auc:0.76087
# [30]	train-auc:0.976432	val-auc:0.765446
# [40]	train-auc:0.978738	val-auc:0.754577
# [50]	train-auc:0.978638	val-auc:0.764874
# Stopping. Best iteration:
# [26]	train-auc:0.973423	val-auc:0.776888
#
# AUC Score (Test): 0.756293
# Recall Score (Test): 0.695652
# 282.3114335675948
# [0]	train-auc:0.815214	val-auc:0.59611
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.923428	val-auc:0.690789
# [20]	train-auc:0.930498	val-auc:0.693364
# [30]	train-auc:0.941831	val-auc:0.695652
# Stopping. Best iteration:
# [4]	train-auc:0.914101	val-auc:0.703661
#
# AUC Score (Test): 0.700229
# Recall Score (Test): 0.608696
# -1.215364176281715
# [0]	train-auc:0.868875	val-auc:0.642518
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.97311	val-auc:0.693625
# [20]	train-auc:0.97093	val-auc:0.708641
# [30]	train-auc:0.975187	val-auc:0.719705
# Stopping. Best iteration:
# [2]	train-auc:0.929713	val-auc:0.735775
#
# AUC Score (Test): 0.718651
# Recall Score (Test): 0.615385
# 5.3479555962364
# [0]	train-auc:0.869989	val-auc:0.596652
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.955272	val-auc:0.700893
# [20]	train-auc:0.960386	val-auc:0.678571
# [30]	train-auc:0.963207	val-auc:0.670089
# Stopping. Best iteration:
# [5]	train-auc:0.935582	val-auc:0.730804
#
# AUC Score (Test): 0.669643
# Recall Score (Test): 0.542857
# -0.3143755252297131
# [0]	train-auc:0.829817	val-auc:0.538889
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.934077	val-auc:0.669167
# [20]	train-auc:0.936714	val-auc:0.688889
# [30]	train-auc:0.948682	val-auc:0.708333
# [40]	train-auc:0.954057	val-auc:0.721111
# [50]	train-auc:0.953144	val-auc:0.718333
# [60]	train-auc:0.956592	val-auc:0.706667
# [70]	train-auc:0.961258	val-auc:0.712222
# Stopping. Best iteration:
# [44]	train-auc:0.955578	val-auc:0.734444
#
# AUC Score (Test): 0.718889
# Recall Score (Test): 0.583333
# -1.058406781655318
# [0]	train-auc:0.763825	val-auc:0.636757
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.885657	val-auc:0.767297
# [20]	train-auc:0.891659	val-auc:0.763514
# [30]	train-auc:0.903868	val-auc:0.813514
# [40]	train-auc:0.908279	val-auc:0.812432
# [50]	train-auc:0.912896	val-auc:0.808108
# [60]	train-auc:0.915256	val-auc:0.805946
# Stopping. Best iteration:
# [34]	train-auc:0.904483	val-auc:0.821622
#
# AUC Score (Test): 0.814054
# Recall Score (Test): 0.840000
# -2.583074951287192
# [0]	train-auc:0.774486	val-auc:0.660837
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.91311	val-auc:0.75583
# [20]	train-auc:0.91835	val-auc:0.756516
# [30]	train-auc:0.936261	val-auc:0.758573
# Stopping. Best iteration:
# [6]	train-auc:0.903773	val-auc:0.794239
#
# AUC Score (Test): 0.760631
# Recall Score (Test): 0.611111
# -1.121189739505877
# [0]	train-auc:0.759921	val-auc:0.717532
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.881151	val-auc:0.812574
# [20]	train-auc:0.897421	val-auc:0.811098
# [30]	train-auc:0.911806	val-auc:0.799292
# Stopping. Best iteration:
# [4]	train-auc:0.843304	val-auc:0.833825
#
# AUC Score (Test): 0.814050
# Recall Score (Test): 0.727273
# -3.975739291743442
# [0]	train-auc:0.849351	val-auc:0.484406
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.938644	val-auc:0.649899
# [20]	train-auc:0.93891	val-auc:0.684105
# [30]	train-auc:0.945296	val-auc:0.677062
# [40]	train-auc:0.952639	val-auc:0.685111
# [50]	train-auc:0.953065	val-auc:0.685614
# [60]	train-auc:0.952746	val-auc:0.695674
# [70]	train-auc:0.955619	val-auc:0.691147
# [80]	train-auc:0.957109	val-auc:0.690141
# [90]	train-auc:0.958067	val-auc:0.686117
# Stopping. Best iteration:
# [61]	train-auc:0.953704	val-auc:0.696177
#
# AUC Score (Test): 0.687626
# Recall Score (Test): 0.392857
# -0.2161574403211271
# [0]	train-auc:0.761015	val-auc:0.696429
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.944764	val-auc:0.809105
# [20]	train-auc:0.957003	val-auc:0.779678
# [30]	train-auc:0.96424	val-auc:0.794769
# Stopping. Best iteration:
# [7]	train-auc:0.932258	val-auc:0.827716
#
# AUC Score (Test): 0.790744
# Recall Score (Test): 0.750000
# -1.299801934001068
# [0]	train-auc:0.740079	val-auc:0.713695
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.919742	val-auc:0.792208
# [20]	train-auc:0.922817	val-auc:0.784534
# [30]	train-auc:0.934921	val-auc:0.776269
# [40]	train-auc:0.931647	val-auc:0.779811
# Stopping. Best iteration:
# [14]	train-auc:0.920833	val-auc:0.803424
#
# AUC Score (Test): 0.775679
# Recall Score (Test): 0.500000
# 1.012100680001032
# [0]	train-auc:0.777265	val-auc:0.584054
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.904483	val-auc:0.795676
# [20]	train-auc:0.926131	val-auc:0.792973
# [30]	train-auc:0.935057	val-auc:0.756216
# [40]	train-auc:0.938443	val-auc:0.764865
# Stopping. Best iteration:
# [18]	train-auc:0.92254	val-auc:0.81027
#
# AUC Score (Test): 0.781622
# Recall Score (Test): 0.400000
# -1.939656045111932
# [0]	train-auc:0.819118	val-auc:0.680833
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.906389	val-auc:0.743333
# [20]	train-auc:0.90568	val-auc:0.752778
# [30]	train-auc:0.908114	val-auc:0.759444
# [40]	train-auc:0.910142	val-auc:0.766667
# [50]	train-auc:0.91643	val-auc:0.760556
# [60]	train-auc:0.92211	val-auc:0.762778
# Stopping. Best iteration:
# [39]	train-auc:0.909939	val-auc:0.77
#
# AUC Score (Test): 0.760000
# Recall Score (Test): 0.583333
# -1.076603198252683
# [0]	train-auc:0.792678	val-auc:0.543763
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.911239	val-auc:0.718058
# [20]	train-auc:0.915283	val-auc:0.725604
# [30]	train-auc:0.927416	val-auc:0.745724
# [40]	train-auc:0.937846	val-auc:0.722082
# [50]	train-auc:0.939974	val-auc:0.736418
# [60]	train-auc:0.937952	val-auc:0.730885
# Stopping. Best iteration:
# [30]	train-auc:0.927416	val-auc:0.745724
#
# AUC Score (Test): 0.730885
# Recall Score (Test): 0.571429
# -2.215102971207137
# [0]	train-auc:0.829953	val-auc:0.713735
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.954073	val-auc:0.757716
# [20]	train-auc:0.959958	val-auc:0.792181
# [30]	train-auc:0.967525	val-auc:0.783436
# [40]	train-auc:0.968471	val-auc:0.779835
# [50]	train-auc:0.971098	val-auc:0.782922
# [60]	train-auc:0.972465	val-auc:0.782922
# Stopping. Best iteration:
# [35]	train-auc:0.96742	val-auc:0.798354
#
# AUC Score (Test): 0.786008
# Recall Score (Test): 0.740741
# -0.6479232902849273
# [0]	train-auc:0.778613	val-auc:0.65535
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.91361	val-auc:0.751543
# [20]	train-auc:0.928954	val-auc:0.743827
# [30]	train-auc:0.940515	val-auc:0.738683
# [40]	train-auc:0.9464	val-auc:0.735597
# Stopping. Best iteration:
# [13]	train-auc:0.919601	val-auc:0.757716
#
# AUC Score (Test): 0.738683
# Recall Score (Test): 0.629630
# -1.067132548678616
# [0]	train-auc:0.817841	val-auc:0.67973
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.913307	val-auc:0.814865
# [20]	train-auc:0.915256	val-auc:0.788108
# [30]	train-auc:0.925721	val-auc:0.791351
# [40]	train-auc:0.92726	val-auc:0.798919
# Stopping. Best iteration:
# [10]	train-auc:0.913307	val-auc:0.814865
#
# AUC Score (Test): 0.798919
# Recall Score (Test): 0.720000
# -0.04387674750747533
# [0]	train-auc:0.785602	val-auc:0.708333
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.944299	val-auc:0.81893
# [20]	train-auc:0.958066	val-auc:0.79784
# [30]	train-auc:0.960168	val-auc:0.78858
# Stopping. Best iteration:
# [5]	train-auc:0.911981	val-auc:0.820216
#
# AUC Score (Test): 0.815844
# Recall Score (Test): 0.666667
# -0.02712478232314355
# [0]	train-auc:0.800525	val-auc:0.622785
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.920472	val-auc:0.756962
# [20]	train-auc:0.938302	val-auc:0.750633
# [30]	train-auc:0.943257	val-auc:0.73481
# [40]	train-auc:0.946318	val-auc:0.736076
# Stopping. Best iteration:
# [13]	train-auc:0.930917	val-auc:0.771519
#
# AUC Score (Test): 0.739241
# Recall Score (Test): 0.600000
# 57.13082047388652
# [0]	train-auc:0.81689	val-auc:0.662726
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.925181	val-auc:0.717304
# [20]	train-auc:0.921669	val-auc:0.734406
# [30]	train-auc:0.93327	val-auc:0.70171
# [40]	train-auc:0.939655	val-auc:0.714286
# Stopping. Best iteration:
# [16]	train-auc:0.933057	val-auc:0.740946
#
# AUC Score (Test): 0.711771
# Recall Score (Test): 0.571429
# -1.261546894429414
# [0]	train-auc:0.79604	val-auc:0.667568
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.928439	val-auc:0.738378
# [20]	train-auc:0.927054	val-auc:0.717838
# [30]	train-auc:0.929517	val-auc:0.733514
# Stopping. Best iteration:
# [6]	train-auc:0.918744	val-auc:0.748649
#
# AUC Score (Test): 0.740000
# Recall Score (Test): 0.480000
# 1.071212430994228
# [0]	train-auc:0.825101	val-auc:0.636111
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.959179	val-auc:0.714444
# [20]	train-auc:0.957302	val-auc:0.696667
# [30]	train-auc:0.966227	val-auc:0.693333
# Stopping. Best iteration:
# [3]	train-auc:0.937475	val-auc:0.733333
#
# AUC Score (Test): 0.697222
# Recall Score (Test): 0.541667
# 3.81897774898936
# [0]	train-auc:0.780456	val-auc:0.770661
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.930754	val-auc:0.819067
# [20]	train-auc:0.938194	val-auc:0.827037
# [30]	train-auc:0.944147	val-auc:0.825266
# Stopping. Best iteration:
# [4]	train-auc:0.914633	val-auc:0.837367
#
# AUC Score (Test): 0.827627
# Recall Score (Test): 0.681818
# -0.889584472113095
# [0]	train-auc:0.76919	val-auc:0.592405
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.918092	val-auc:0.586709
# [20]	train-auc:0.922707	val-auc:0.622152
# [30]	train-auc:0.924164	val-auc:0.643038
# Stopping. Best iteration:
# [1]	train-auc:0.814856	val-auc:0.671519
#
# AUC Score (Test): 0.643671
# Recall Score (Test): 0.700000
# -1.113315266826315
# [0]	train-auc:0.820206	val-auc:0.554791
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.94943	val-auc:0.721537
# [20]	train-auc:0.958458	val-auc:0.703985
# [30]	train-auc:0.963997	val-auc:0.713472
# [40]	train-auc:0.964551	val-auc:0.719165
# [50]	train-auc:0.967985	val-auc:0.726755
# [60]	train-auc:0.970311	val-auc:0.732922
# [70]	train-auc:0.973413	val-auc:0.737192
# [80]	train-auc:0.972748	val-auc:0.730076
# [90]	train-auc:0.974742	val-auc:0.733871
# Stopping. Best iteration:
# [69]	train-auc:0.97297	val-auc:0.73814
#
# AUC Score (Test): 0.733397
# Recall Score (Test): 0.677419
# -2.111351473064265
# [0]	train-auc:0.802434	val-auc:0.689167
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.942596	val-auc:0.767222
# [20]	train-auc:0.943002	val-auc:0.781667
# [30]	train-auc:0.950304	val-auc:0.773333
# [40]	train-auc:0.963083	val-auc:0.771667
# [50]	train-auc:0.96643	val-auc:0.771667
# Stopping. Best iteration:
# [23]	train-auc:0.947363	val-auc:0.791667
#
# AUC Score (Test): 0.766667
# Recall Score (Test): 0.791667
# -1.163541633106762
# [0]	train-auc:0.838781	val-auc:0.734568
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.908671	val-auc:0.759774
# [20]	train-auc:0.917604	val-auc:0.761574
# [30]	train-auc:0.921492	val-auc:0.764918
# Stopping. Best iteration:
# [8]	train-auc:0.909143	val-auc:0.770833
#
# AUC Score (Test): 0.763889
# Recall Score (Test): 0.703704
# -2.08501455430492
# [0]	train-auc:0.842937	val-auc:0.558913
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.976048	val-auc:0.693529
# [20]	train-auc:0.977128	val-auc:0.689866
# [30]	train-auc:0.978698	val-auc:0.690476
# [40]	train-auc:0.980367	val-auc:0.689255
# [50]	train-auc:0.978404	val-auc:0.692918
# Stopping. Best iteration:
# [26]	train-auc:0.976637	val-auc:0.703907
#
# AUC Score (Test): 0.690476
# Recall Score (Test): 0.476190
# -0.5765741831005211
# [0]	train-auc:0.767498	val-auc:0.720391
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.920438	val-auc:0.749695
# [20]	train-auc:0.930107	val-auc:0.767399
# [30]	train-auc:0.939923	val-auc:0.764347
# [40]	train-auc:0.946206	val-auc:0.783272
# [50]	train-auc:0.950034	val-auc:0.772283
# Stopping. Best iteration:
# [24]	train-auc:0.935113	val-auc:0.798535
#
# AUC Score (Test): 0.771673
# Recall Score (Test): 0.809524
# -0.9151765083216702
# [0]	train-auc:0.815365	val-auc:0.602222
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.915974	val-auc:0.773333
# [20]	train-auc:0.930629	val-auc:0.786944
# [30]	train-auc:0.938742	val-auc:0.762778
# [40]	train-auc:0.93854	val-auc:0.751667
# Stopping. Best iteration:
# [16]	train-auc:0.926572	val-auc:0.816111
#
# AUC Score (Test): 0.748333
# Recall Score (Test): 0.625000
# 14.93629661332529
# [0]	train-auc:0.82501	val-auc:0.734177
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.939662	val-auc:0.760127
# [20]	train-auc:0.945394	val-auc:0.787975
# ...
# Stopping. Best iteration:
# [11]	train-auc:0.909428	val-auc:0.781579
#
# AUC Score (Test): 0.759211
# Recall Score (Test): 0.473684
# -1.449097679533837
# [0]	train-auc:0.789633	val-auc:0.788666
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.903621	val-auc:0.846812
# [20]	train-auc:0.935665	val-auc:0.855962
# [30]	train-auc:0.937897	val-auc:0.836482
# [40]	train-auc:0.948214	val-auc:0.844156
# [50]	train-auc:0.956845	val-auc:0.867769
# [60]	train-auc:0.962599	val-auc:0.874852
# [70]	train-auc:0.965179	val-auc:0.868949
# [80]	train-auc:0.96498	val-auc:0.874852
# [90]	train-auc:0.966171	val-auc:0.876623
# [100]	train-auc:0.968948	val-auc:0.872491
# [110]	train-auc:0.971627	val-auc:0.873672
# Stopping. Best iteration:
# [84]	train-auc:0.965179	val-auc:0.879575
#
# AUC Score (Test): 0.877214
# Recall Score (Test): 0.818182
# -0.8883075305974905
# [0]	train-auc:0.788539	val-auc:0.619869
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.918933	val-auc:0.702425
# [20]	train-auc:0.937079	val-auc:0.723414
# [30]	train-auc:0.945618	val-auc:0.730877
# Stopping. Best iteration:
# [3]	train-auc:0.901629	val-auc:0.781017
#
# AUC Score (Test): 0.717817
# Recall Score (Test): 0.437500
# 2.43354941045487
# [0]	train-auc:0.765873	val-auc:0.574085
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.942659	val-auc:0.839433
# [20]	train-auc:0.947619	val-auc:0.827627
# [30]	train-auc:0.949008	val-auc:0.817591
# Stopping. Best iteration:
# [8]	train-auc:0.933829	val-auc:0.847993
#
# AUC Score (Test): 0.828217
# Recall Score (Test): 0.636364
# -2.303903612438139
# [0]	train-auc:0.83193	val-auc:0.557982
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.943182	val-auc:0.649473
# [20]	train-auc:0.948747	val-auc:0.612952
# [30]	train-auc:0.95202	val-auc:0.621235
# Stopping. Best iteration:
# [6]	train-auc:0.930135	val-auc:0.666039
#
# AUC Score (Test): 0.624247
# Recall Score (Test): 0.562500
# 1.413432757176257
# [0]	train-auc:0.826775	val-auc:0.600556
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.948884	val-auc:0.740833
# [20]	train-auc:0.946349	val-auc:0.733889
# [30]	train-auc:0.957404	val-auc:0.739444
# [40]	train-auc:0.958519	val-auc:0.719444
# Stopping. Best iteration:
# [12]	train-auc:0.950101	val-auc:0.754167
#
# AUC Score (Test): 0.726667
# Recall Score (Test): 0.458333
# -1.159817220352915
# [0]	train-auc:0.806199	val-auc:0.5633
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.930782	val-auc:0.692365
# [20]	train-auc:0.939946	val-auc:0.700493
# [30]	train-auc:0.946846	val-auc:0.700493
# [40]	train-auc:0.94814	val-auc:0.70197
# Stopping. Best iteration:
# [13]	train-auc:0.935741	val-auc:0.71601
#
# AUC Score (Test): 0.701970
# Recall Score (Test): 0.413793
# -0.7337976072093357
# [0]	train-auc:0.81114	val-auc:0.585134
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.935891	val-auc:0.729681
# [20]	train-auc:0.946453	val-auc:0.696245
# [30]	train-auc:0.953862	val-auc:0.701132
# Stopping. Best iteration:
# [9]	train-auc:0.931266	val-auc:0.731224
#
# AUC Score (Test): 0.717078
# Recall Score (Test): 0.481481
# 0.9262263630766244
# [0]	train-auc:0.761209	val-auc:0.788108
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.916898	val-auc:0.844324
# [20]	train-auc:0.93557	val-auc:0.834054
# [30]	train-auc:0.935467	val-auc:0.831892
# [40]	train-auc:0.93834	val-auc:0.809189
# Stopping. Best iteration:
# [16]	train-auc:0.929619	val-auc:0.862162
#
# AUC Score (Test): 0.820541
# Recall Score (Test): 0.840000
# -1.974452701412157
# [0]	train-auc:0.838602	val-auc:0.65166
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.97004	val-auc:0.739437
# [20]	train-auc:0.969774	val-auc:0.720825
# [30]	train-auc:0.974457	val-auc:0.697686
# Stopping. Best iteration:
# [4]	train-auc:0.956577	val-auc:0.751509
#
# AUC Score (Test): 0.705231
# Recall Score (Test): 0.571429
# -0.655691351171522
# [0]	train-auc:0.806744	val-auc:0.6375
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.94645	val-auc:0.762222
# [20]	train-auc:0.976876	val-auc:0.781667
# [30]	train-auc:0.98357	val-auc:0.753333
# [40]	train-auc:0.9857	val-auc:0.771111
# Stopping. Best iteration:
# [12]	train-auc:0.958114	val-auc:0.808889
#
# AUC Score (Test): 0.773333
# Recall Score (Test): 0.541667
# -1.254151274818204
# [0]	train-auc:0.815044	val-auc:0.62039
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.914037	val-auc:0.736038
# [20]	train-auc:0.917774	val-auc:0.751844
# [30]	train-auc:0.930129	val-auc:0.746048
# [40]	train-auc:0.943106	val-auc:0.744468
# [50]	train-auc:0.946117	val-auc:0.738145
# Stopping. Best iteration:
# [23]	train-auc:0.917255	val-auc:0.761328
#
# AUC Score (Test): 0.741307
# Recall Score (Test): 0.538462
# -0.889584472113095
# [0]	train-auc:0.790807	val-auc:0.655405
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.914025	val-auc:0.764324
# [20]	train-auc:0.915461	val-auc:0.744324
# [30]	train-auc:0.923874	val-auc:0.783784
# [40]	train-auc:0.929004	val-auc:0.780541
# [50]	train-auc:0.935673	val-auc:0.804324
# [60]	train-auc:0.933723	val-auc:0.792973
# [70]	train-auc:0.937109	val-auc:0.790811
# [80]	train-auc:0.936596	val-auc:0.781622
# Stopping. Best iteration:
# [52]	train-auc:0.936698	val-auc:0.808108
#
# AUC Score (Test): 0.780000
# Recall Score (Test): 0.720000
# -1.224941237648749
# [0]	train-auc:0.767546	val-auc:0.705479
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.879568	val-auc:0.731823
# [20]	train-auc:0.901422	val-auc:0.724974
# [30]	train-auc:0.904018	val-auc:0.728135
# [40]	train-auc:0.907132	val-auc:0.725501
# Stopping. Best iteration:
# [13]	train-auc:0.890729	val-auc:0.74236
#
# AUC Score (Test): 0.729189
# Recall Score (Test): 0.653846
# -1.051277191526526
# [0]	train-auc:0.828768	val-auc:0.658649
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.945316	val-auc:0.823243
# [20]	train-auc:0.958962	val-auc:0.805405
# [30]	train-auc:0.965015	val-auc:0.806486
# Stopping. Best iteration:
# [8]	train-auc:0.946189	val-auc:0.835135
#
# AUC Score (Test): 0.814054
# Recall Score (Test): 0.760000
# -0.2538804209279459
# [0]	train-auc:0.768024	val-auc:0.708861
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.867567	val-auc:0.748101
# [20]	train-auc:0.87636	val-auc:0.743671
# [30]	train-auc:0.893607	val-auc:0.74462
# [40]	train-auc:0.911193	val-auc:0.759494
# Stopping. Best iteration:
# [18]	train-auc:0.876943	val-auc:0.767722
#
# AUC Score (Test): 0.753165
# Recall Score (Test): 0.800000
# -0.5039353649853544
# [0]	train-auc:0.780135	val-auc:0.673355
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.904329	val-auc:0.681579
# [20]	train-auc:0.916306	val-auc:0.643421
# [30]	train-auc:0.923954	val-auc:0.664474
# [40]	train-auc:0.925734	val-auc:0.669079
# Stopping. Best iteration:
# [11]	train-auc:0.905387	val-auc:0.684211
#
# AUC Score (Test): 0.671053
# Recall Score (Test): 0.526316
# -6.338400330990825
# [0]	train-auc:0.747925	val-auc:0.724095
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.90315	val-auc:0.747736
# [20]	train-auc:0.90778	val-auc:0.755533
# [30]	train-auc:0.911611	val-auc:0.764085
# Stopping. Best iteration:
# [3]	train-auc:0.864889	val-auc:0.818913
#
# AUC Score (Test): 0.764588
# Recall Score (Test): 0.535714
# -1.121615386677745
# [0]	train-auc:0.834177	val-auc:0.72255
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.92381	val-auc:0.809917
# [20]	train-auc:0.934028	val-auc:0.809327
# [30]	train-auc:0.93879	val-auc:0.802243
# [40]	train-auc:0.940476	val-auc:0.811098
# Stopping. Best iteration:
# [17]	train-auc:0.931845	val-auc:0.85242
#
# AUC Score (Test): 0.811098
# Recall Score (Test): 0.727273
# -3.939080429066294
# [0]	train-auc:0.789219	val-auc:0.661217
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.951362	val-auc:0.776157
# [20]	train-auc:0.960409	val-auc:0.782193
# [30]	train-auc:0.96871	val-auc:0.789738
# [40]	train-auc:0.971477	val-auc:0.784205
# Stopping. Best iteration:
# [12]	train-auc:0.953704	val-auc:0.792757
#
# AUC Score (Test): 0.778672
# Recall Score (Test): 0.678571
# -0.6026482647312369
# [0]	train-auc:0.77511	val-auc:0.757568
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.906638	val-auc:0.798378
# [20]	train-auc:0.918744	val-auc:0.784865
# [30]	train-auc:0.933723	val-auc:0.798378
# Stopping. Best iteration:
# [6]	train-auc:0.89566	val-auc:0.810811
#
# AUC Score (Test): 0.791892
# Recall Score (Test): 0.440000
# -0.2224889420026667
# [0]	train-auc:0.869218	val-auc:0.678325
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.937035	val-auc:0.631773
# [20]	train-auc:0.940701	val-auc:0.633498
# [30]	train-auc:0.947062	val-auc:0.635961
# Stopping. Best iteration:
# [3]	train-auc:0.921132	val-auc:0.681281
#
# AUC Score (Test): 0.642857
# Recall Score (Test): 0.448276
# -1.092511761301257
# [0]	train-auc:0.797921	val-auc:0.634722
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.940974	val-auc:0.802222
# [20]	train-auc:0.951724	val-auc:0.796111
# [30]	train-auc:0.960041	val-auc:0.813889
# [40]	train-auc:0.962069	val-auc:0.818889
# [50]	train-auc:0.960649	val-auc:0.827222
# [60]	train-auc:0.961562	val-auc:0.835556
# [70]	train-auc:0.96288	val-auc:0.833333
# [80]	train-auc:0.961968	val-auc:0.835556
# [90]	train-auc:0.962373	val-auc:0.844444
# [100]	train-auc:0.962677	val-auc:0.847222
# [110]	train-auc:0.962373	val-auc:0.848889
# [120]	train-auc:0.962576	val-auc:0.847222
# [130]	train-auc:0.963692	val-auc:0.845833
# Stopping. Best iteration:
# [108]	train-auc:0.962576	val-auc:0.85
#
# AUC Score (Test): 0.846667
# Recall Score (Test): 0.666667
# -2.240162948450878
# [0]	train-auc:0.809381	val-auc:0.604722
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.929513	val-auc:0.69
# [20]	train-auc:0.939351	val-auc:0.701667
# [30]	train-auc:0.938844	val-auc:0.741111
# [40]	train-auc:0.941075	val-auc:0.746111
# [50]	train-auc:0.941075	val-auc:0.751111
# [60]	train-auc:0.942596	val-auc:0.762778
# [70]	train-auc:0.944726	val-auc:0.775
# [80]	train-auc:0.946247	val-auc:0.784444
# [90]	train-auc:0.948276	val-auc:0.780556
# [100]	train-auc:0.949696	val-auc:0.770556
# Stopping. Best iteration:
# [79]	train-auc:0.946349	val-auc:0.787222
#
# AUC Score (Test): 0.773889
# Recall Score (Test): 0.375000
# -2.178656932115923
# [0]	train-auc:0.834954	val-auc:0.65
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.956731	val-auc:0.79372
# [20]	train-auc:0.96427	val-auc:0.77971
# [30]	train-auc:0.96722	val-auc:0.776812
# Stopping. Best iteration:
# [9]	train-auc:0.951486	val-auc:0.795652
#
# AUC Score (Test): 0.785507
# Recall Score (Test): 0.733333
# -0.2902732541226766
# [0]	train-auc:0.782642	val-auc:0.705419
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.87655	val-auc:0.803941
# [20]	train-auc:0.90221	val-auc:0.815764
# [30]	train-auc:0.925067	val-auc:0.828079
# [40]	train-auc:0.93186	val-auc:0.82266
# [50]	train-auc:0.929811	val-auc:0.825123
# Stopping. Best iteration:
# [25]	train-auc:0.911806	val-auc:0.834975
#
# AUC Score (Test): 0.819212
# Recall Score (Test): 0.551724
# -4.023464980889163
# [0]	train-auc:0.853874	val-auc:0.585513
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.941677	val-auc:0.671529
# [20]	train-auc:0.943061	val-auc:0.679577
# [30]	train-auc:0.952427	val-auc:0.677062
# [40]	train-auc:0.954023	val-auc:0.682093
# Stopping. Best iteration:
# [11]	train-auc:0.939974	val-auc:0.684105
#
# AUC Score (Test): 0.678068
# Recall Score (Test): 0.464286
# 1.789172798142906
# [0]	train-auc:0.771827	val-auc:0.701081
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.900482	val-auc:0.759189
# [20]	train-auc:0.911768	val-auc:0.792703
# [30]	train-auc:0.918026	val-auc:0.778919
# [40]	train-auc:0.926131	val-auc:0.787568
# [50]	train-auc:0.923566	val-auc:0.778919
# Stopping. Best iteration:
# [24]	train-auc:0.910434	val-auc:0.79973
#
# AUC Score (Test): 0.780541
# Recall Score (Test): 0.600000
# -1.288149842671176
# [0]	train-auc:0.817016	val-auc:0.645153
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.943522	val-auc:0.791886
# [20]	train-auc:0.960963	val-auc:0.812961
# [30]	train-auc:0.973526	val-auc:0.818757
# [40]	train-auc:0.976329	val-auc:0.807692
# Stopping. Best iteration:
# [17]	train-auc:0.963455	val-auc:0.82666
#
# AUC Score (Test): 0.809800
# Recall Score (Test): 0.807692
# -0.6222248422833853
# [0]	train-auc:0.726379	val-auc:0.75
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.945455	val-auc:0.721965
# [20]	train-auc:0.959222	val-auc:0.716564
# [30]	train-auc:0.965318	val-auc:0.735597
# Stopping. Best iteration:
# [0]	train-auc:0.726379	val-auc:0.75
#
# AUC Score (Test): 0.735597
# Recall Score (Test): 0.518519
# -0.9990822070761882
# [0]	train-auc:0.818014	val-auc:0.60443
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.913331	val-auc:0.675
# [20]	train-auc:0.916294	val-auc:0.677848
# [30]	train-auc:0.922658	val-auc:0.664557
# Stopping. Best iteration:
# [3]	train-auc:0.883162	val-auc:0.719304
#
# AUC Score (Test): 0.671519
# Recall Score (Test): 0.400000
# -0.8430825185864947
# [0]	train-auc:0.789706	val-auc:0.638889
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 30 rounds.
# [10]	train-auc:0.943509	val-auc:0.656389
# [20]	train-auc:0.946856	val-auc:0.685
# [30]	train-auc:0.950811	val-auc:0.680556
# [40]	train-auc:0.953448	val-auc:0.695
# [50]	train-auc:0.953448	val-auc:0.692778
# [60]	train-auc:0.956592	val-auc:0.690556
# Stopping. Best iteration:
# [38]	train-auc:0.953245	val-auc:0.702222
#
# AUC Score (Test): 0.693889
# Recall Score (Test): 0.541667
# Text(0,0.5,'Feature Importances')

# %%
# joblib.dump(xgb_list, "m_save/xgb_z_250_三个月.m")
xgb_list = joblib.load('m_save/xgb_z.m')

# %% [markdown]
# ## 原数据回测

# %%
get_zxy(simple=True)

# %%
xga = xgb.DMatrix(data_a[list_]);xg0 = xgb.DMatrix(re_of_de_0[list_]);xg1 = xgb.DMatrix(re_of_de_1[list_])
for j in zip(['xga','xg0','xg1'],['data_a_target','re_target_0','re_target_1']):
    e = [i.predict(eval(j[0])) for i in xgb_list]
    print(f'---{j[0]}---\n',metrics.confusion_matrix(eval(j[1]),
                                                   np.where(np.array([sum(i)/len(xgb_list) for i in list(zip(*e))])>=0.5,1,0)),'\n-----------')
del xga,xg0,xg1
# Out:
# ---xga---
#  [[22563   511]
#  [    0     0]]
# -----------
# ---xg0---
#  [[325  84]
#  [  0   0]]
# -----------
# ---xg1---
#  [[ 0  0]
#  [19 63]]
# -----------

# %% [markdown]
# ## 预测

# %%
data_2018[list_].shape
# Out:
# (2810, 10)

# %%
xgb_list[0].feature_names
# Out:
# ['获息倍数',
#  '货币资金/短期债务',
#  '净利润(亿元)',
#  '筹资活动现金流(亿元)',
#  '主营业务利润率(%)',
#  '主营业务收入增长率(%)',
#  '投资活动现金流(亿元)',
#  '净资产回报率(%)',
#  '总资产报酬率(%)',
#  '流动比率']

# %%
xg_2018 = xgb.DMatrix(data_2018[list_])
e_xgb = [i.predict(xg_2018) for i in xgb_list]
e_xgb = np.array([sum(i)/len(xgb_list) for i in list(zip(*e_xgb))])
f = np.where(e_xgb>=0.5,1,0)
del xg_2018
f.sum()
# Out:
# 334

# %% [markdown]
# ## 数据提取

# %%
e_xgb[data_2018_object['名称'].map(lambda x:x.find('新疆生产建设兵团第六师国有资产经营有限责任公司')>=0)]
# Out:
# array([0.48229144])

# %%
dict(zip(data_2018_object.loc[dlgindex|zjgindex|xmgindex,'名称'],e_xgb[dlgindex|zjgindex|xmgindex]))
# Out:
# {'湛江港(集团)股份有限公司': 0.466981696665287,
#  '大连港股份有限公司': 0.5033089598417282,
#  '厦门港务控股集团有限公司': 0.4768005536794662}

# %%
dlgindex = data_2018_object['名称'].map(lambda x:(x.find('大连港股份')>=0))
zjgindex = data_2018_object['名称'].map(lambda x:(x.find('湛江港')>=0))
xmgindex = data_2018_object['名称'].map(lambda x:(x.find('厦门港务控股')>=0))

# %%
a = pd.concat([data_2018_object.loc[dlgindex|zjgindex|xmgindex,'名称'],data_2018.loc[dlgindex|zjgindex|xmgindex,list_]],axis=1).set_index(['名称'])

# %%
a.stack().unstack(0).plot()
plt.xticks([i for i in range(a.shape[1])],a.columns,fontsize=12)
plt.legend(fontsize=15,loc='best')

# %%
plt.figure()
for i in range(len(a.columns)):
    ax = plt.subplot(5,2,i+1)
    plt.barh(a.index,a.iloc[:,i],0.5)
    plt.title(a.columns[i])
    plt.xticks(rotation=20)

# %% [markdown]
# # 随即森林+栅栏搜索

# %% [markdown]
# ## 栅栏搜索

# %%
rfc = RandomForestClassifier(oob_score=True,class_weight={1:10,0:1})

para_list = {
    'n_estimators':range(30,180,5),
    'max_depth':[2,3,4,],
    'min_samples_split':range(2,11,2),
    'max_features':[i/100 for i in range(50,71,5)],
}

flod = KFold(n_splits=4)
grid = GridSearchCV(rfc,param_grid=para_list,scoring='roc_auc',cv=flod,n_jobs=-1)

# %%
grid.fit(x1,y1)

## 保存模型

# joblib.dump(grid, "m_save/违约公司纵向比较全特征_auc.m")

## 读取模型

grid_recall = joblib.load('m_save/违约公司纵向比较全特征_recall.m')
grid_auc = joblib.load('m_save/违约公司纵向比较全特征_auc.m')

## 模型参数

print(grid_auc.best_params_)
print('\n--------\n',grid_auc.best_params_)
grid_auc = grid_auc.best_estimator_
grid_recall = grid_recall.best_estimator_

# %% [markdown]
# ## 特征重要性

# %%
dict_auc = dict(zip(x2.columns,grid_auc.feature_importances_))
dict_recall = dict(zip(x2.columns,grid_recall.feature_importances_))

# %% [markdown]
# ## 更新训练集、测试集

# %%
get_zxy()

# %% [markdown]
# ## 模型效果在原数据上的混淆矩阵

# %%
for j in zip(['data_a','re_of_de_0','re_of_de_1'],['data_a_target','re_target_0','re_target_1']):
    for i in ['grid_auc','grid_recall']:
        print(f'{i}---{j[0]}',metrics.confusion_matrix(eval(j[1]),eval(i).predict(eval(j[0]))),'\n-----------')
# Out:
# grid_auc---data_a [[15558    53]
#  [    0     0]]
# -----------
# grid_recall---data_a [[15561    50]
#  [    0     0]]
# -----------
# grid_auc---re_of_de_0 [[437  13]
#  [  0   0]]
# -----------
# grid_recall---re_of_de_0 [[447   3]
#  [  0   0]]
# -----------
# grid_auc---re_of_de_1 [[ 0  0]
#  [13 13]]
# -----------
# grid_recall---re_of_de_1 [[ 0  0]
#  [17  9]]
# -----------

# %% [markdown]
# ## 训练模型

# %%
rfc_list = []
rfc_recall = []
rfc_epoch = 100
for i in range(rfc_epoch):
    get_zxy(test_size=0.25,simple=True)
    rfc = RandomForestClassifier(n_estimators=np.random.choice(range(20,30)),
                                 max_depth=np.random.choice([2,3],p=[0.5,0.5,]),
                                 max_features=np.random.choice([i/100 for i in range(35,55)]),
                                 min_samples_split=np.random.choice([3,4,5],p=[0.15,0.45,0.4]),
                                 n_jobs=-1,class_weight='balanced')
    rfc.fit(x1,y1)
    rfc_recall.append(metrics.recall_score(y2,rfc.predict(x2)))
    rfc_list.append(rfc)
    if i == 0:
        feature_importance = rfc.feature_importances_
    else :
        feature_importance += rfc.feature_importances_
    if i%30 == 0:
        print(i)
feature_importance = [round(i/rfc_epoch,6) for i in feature_importance]
print('avg-recall:',sum(rfc_recall)/rfc_epoch)
pd.Series(dict(zip(x2.columns,feature_importance))).sort_values().plot(kind='barh')
# Out:
# 0
# 30
# 60
# 90
# avg-recall: 0.5185545087003685

# %%
print('\n',np.array(sorted(dict(zip(x2.columns,feature_importance)).items(),key=lambda x:x[1],reverse=True)))
# Out:
#  [['主营业务利润率(%)' '0.140116']
#  ['净资产回报率(%)' '0.131204']
#  ['净利润(亿元)' '0.122906']
#  ['获息倍数' '0.111095']
#  ['流动比率' '0.09749']
#  ['主营业务收入增长率(%)' '0.093511']
#  ['筹资活动现金流(亿元)' '0.085014']
#  ['总资产报酬率(%)' '0.080298']
#  ['货币资金/短期债务' '0.075792']
#  ['投资活动现金流(亿元)' '0.062573']]

# %%
# joblib.dump(rfc_list, "m_save/rfc_z_250_三个月.m")

# %%
rfc_list = joblib.load("m_save/clf_grid12.m")

# %% [markdown]
# ## 原数据回测

# %%
get_hxy()

# %%
for j in zip(['data_a','re_of_de_0','re_of_de_1'],['data_a_target','re_target_0','re_target_1']):
    e = [i.predict_proba(eval(j[0])[list_])[:,1] for i in rfc_list]
    print(f'---{j[0]}---\n',metrics.confusion_matrix(eval(j[1]),
                                                   np.where(np.array([sum(i)/rfc_epoch for i in list(zip(*e))])>=0.5,1,0)),'\n-----------')
# [ 1 if ((sum(i)/epoch)>=0.5) else 0 for i in list(zip(*e)) ]
# Out:
# ---data_a---
#  [[22237   837]
#  [    0     0]]
# -----------
# ---re_of_de_0---
#  [[370  39]
#  [  0   0]]
# -----------
# ---re_of_de_1---
#  [[ 0  0]
#  [34 48]]
# -----------

# %% [markdown]
# ## 预测

# %%
e_rfc = [i.predict_proba(data_2018[list_])[:,1] for i in rfc_list]
e_rfc = np.array([sum(i)/len(rfc_list) for i in list(zip(*e_rfc))])
f = np.where(e_rfc>=0.5,1,0)

f.sum()
# Out:
# 113

# %% [markdown]
# ## 数据提取

# %%
e_rfc[data_2018_object['名称'].map(lambda x:x.find('新疆生产建设兵团第六师国有资产经营有限责任公司')>=0)]
# Out:
# array([0.38275803])

# %%
data_2018.loc[data_2018_object['名称'].map(lambda x: True if x.find('新疆生产建设兵团第六师国有资产经营有限责任公司')!=-1 else False),:]
# Out:
#        总资产(亿元)  货币资产(亿元)   净资产(亿元)   总债务(亿元)  带息债务(亿元)   净债务(亿元)  经营活动现金流(亿元)  \
# 1723  0.802212 -1.047194  2.233281  0.394321  0.756973  1.508769     0.313063
#
#       投资活动现金流(亿元)  筹资活动现金流(亿元)  主营业务收入(亿元)     ...      净利润/带息债务  企业性质_中央国有企业  \
# 1723     0.277939    -0.823264   -0.576479     ...     -1.885398            0
#
#       企业性质_其他  企业性质_地方国有企业  企业性质_民营企业  是否上市_否  是否上市_是  注册资本(万元)_1  注册资本(万元)_2  \
# 1723        0            1          0       1       0           0           0
#
#       注册资本(万元)_3
# 1723           1
#
# [1 rows x 35 columns]

# %% [markdown]
# ## LR

# %%
para_list = {
    'lr__penalty':['l2','l1'],
    'lr__tol':[i/10000 for i in range(1,101,20)],
    'lr__C':[0.1,0.5,1,5,10],
    'lr__class_weight':[dict([(0,i),(1,1-i)]) for i in np.linspace(0.1,0.5,5)]+['balanced']
}

pp_lr = Pipeline([('pn',PolynomialFeatures()),
                      ('lr',LogisticRegression(fit_intercept=False,))])
nflod = KFold(n_splits=4,shuffle=True)
grid = GridSearchCV(pp_lr,para_list,n_jobs=-1,cv=nflod,scoring='recall')

# %%
get_zxy()
grid.fit(x1,y1)

# %%
grid.best_params_
# Out:
# {'lr__C': 1,
#  'lr__class_weight': 'balanced',
#  'lr__penalty': 'l1',
#  'lr__tol': 0.0081}

# %%
lr_epoch = 10
lr_list = []
for i in range(lr_epoch):
    get_zxy(length_0=.4,simple=True)
    lr = LogisticRegression(fit_intercept=False,C=np.random.choice([2,4,6],p=[0.3,0.4,0.3]),
                    class_weight=np.random.choice(['balanced',]+[dict([(0,i),(1,1-i)]) for i in np.linspace(0.2,0.4,3)],p=[0.25,0.25,0.25,0.25]),
                    penalty=np.random.choice(['l1','l2'],p=[0.25,0.75]),
                    tol=np.random.choice([i/50 for i in range(74,87,2)],)           )
    lr.fit(x1,y1)
    lr_list.append(lr)
    if i == 0:
        feature_weight = np.array(lr.coef_).reshape(-1)
    else:
        feature_weight += np.array(lr.coef_).reshape(-1)

feature_weight = pd.Series(feature_weight/lr_epoch,index=x2.columns).sort_values()
feature_weight.plot(kind='barh',title=f'lr of epoch({lr_epoch})')

# %% [markdown]
# ## 回测原数据

# %%
for j in zip(['data_a','re_of_de_0','re_of_de_1'],['data_a_target','re_target_0','re_target_1']):
    e = [i.predict_proba(eval(j[0])[list_])[:,1] for i in lr_list]
    print(f'---{j[0]}---\n',metrics.confusion_matrix(eval(j[1]),
                                                   np.where(np.array([sum(i)/lr_epoch for i in list(zip(*e))])>=0.5,1,0)),'\n-----------')
# Out:
# ---data_a---
#  [[14195  8879]
#  [    0     0]]
# -----------
# ---re_of_de_0---
#  [[187 222]
#  [  0   0]]
# -----------
# ---re_of_de_1---
#  [[ 0  0]
#  [19 63]]
# -----------

# %% [markdown]
# ## 预测

# %%
e_lr = [i.predict_proba(data_2018[list_])[:,1] for i in lr_list]
e_lr = np.array([sum(i)/lr_epoch for i in list(zip(*e_lr))])
f = np.where(e_lr>=0.5,1,0)

f.sum()
# Out:
# 1037

# %% [markdown]
# ## 数据提取

# %%
e_lr[data_2018_object['名称'].map(lambda x:x.find('新光')>=0)]

# %% [markdown]
# ## SVM

# %%
para_list = {'C':[1,5,10],
             'kernel':['linear','poly','rbf'],
             'degree':[2,3]}
svc = SVC(class_weight='balanced',)
nflod = KFold(n_splits=4,shuffle=True)
grid = GridSearchCV(svc,para_list,n_jobs=-1,cv=nflod,scoring='roc_auc')

# %%
get_zxy(simple=True)
grid.fit(x1,y1)
# Out:
# GridSearchCV(cv=KFold(n_splits=4, random_state=None, shuffle=True),
#        error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid={'C': [1, 5, 10], 'kernel': ['linear', 'poly', 'rbf'], 'degree': [2, 3]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='roc_auc', verbose=0)

# %%
grid.best_params_
# Out:
# {'C': 1, 'degree': 2, 'kernel': 'rbf'}

# %%
svc_epoch = 10
svc_list = []
for i in range(svc_epoch):
    get_zxy(length_0=.4,simple=True)
    svc = SVC(C=np.random.choice([1,5],p=[0.6,0.4],),class_weight='balanced',
              kernel=str(np.random.choice(['linear','rbf','poly'],p=[0.5,0.25,0.25])),
              degree=np.random.choice([2,3]),probability=True)
    svc.fit(x1,y1,)
    svc_list.append(svc)
#     if i == 0:
#         feature_weight = np.array(lr.coef_).reshape(-1)
#     else:
#         feature_weight += np.array(lr.coef_).reshape(-1)

# feature_weight = pd.Series(feature_weight/lr_epoch,index=x2.columns).sort_values()
# feature_weight.plot(kind='barh',title=f'lr of epoch({lr_epoch})')

# %% [markdown]
# ## 原数据回测

# %%
for j in zip(['data_a','re_of_de_0','re_of_de_1'],['data_a_target','re_target_0','re_target_1']):
    e = [i.predict_proba(eval(j[0])[list_])[:,1] for i in svc_list]
    print(f'---{j[0]}---\n',metrics.confusion_matrix(eval(j[1]),
                                                   np.where(np.array([sum(i)/svc_epoch for i in list(zip(*e))])>=0.5,1,0)),'\n-----------')
# Out:
# ---data_a---
#  [[22995    79]
#  [    0     0]]
# -----------
# ---re_of_de_0---
#  [[409]]
# -----------
# ---re_of_de_1---
#  [[ 0  0]
#  [52 30]]
# -----------

# %% [markdown]
# ## 预测

# %%
e_svc = [i.predict_proba(data_2018[list_])[:,1] for i in svc_list]
e_svc = np.array([sum(i)/svc_epoch for i in list(zip(*e_svc))])
f = np.where(e_svc>=0.5,1,0)

f.sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-500c50ef8906> in <module>()
# ----> 1 e_svc = [i.predict_proba(data_2018[list_])[:,1] for i in svc_list]
#       2 e_svc = np.array([sum(i)/svc_epoch for i in list(zip(*e_svc))])
#       3 f = np.where(e_svc>=0.5,1,0)
#       4
#       5 f.sum()
#
# NameError: name 'svc_list' is not defined

# %% [markdown]
# ## 提取数据

# %%
e_svc[data_2018_object['名称'].map(lambda x:x.find('新光')>=0)]

# %% [markdown]
# # -------------------------------------------------

# %% [markdown]
# # 提取原数据

# %%
index_ = pd.concat([data_a_object,data_2018_object])['名称'].map(lambda x : x.find('新疆生产建设兵团第六师国有资产经营有限责任公司')>=0)

# %%
outdata = pd.concat([pd.concat([data_a_object,data_2018_object]).loc[index_,['名称','报告期']],\
                     pd.concat([data_a,data_2018]).loc[index_,:]],axis=1)

# %%
# outdata.to_excel(path+'新疆生产建设兵团第六师国有资产经营有限责任公司.xlsx',index=False)

# %%
outdata = outdata.iloc[:,:-9]

get_zxy(simple=True)

outdata = outdata[list(outdata.columns[:2])+list_+['经营活动现金流(亿元)']]

outdata.set_index('报告期',inplace=True)

outdata.sort_values('报告期',inplace=True)

# %%
outdata
# Out:
#                                  名称      获息倍数  货币资金/短期债务   净利润(亿元)  \
# 报告期
# 2016-03-31  新疆生产建设兵团第六师国有资产经营有限责任公司 -1.450960   0.735140 -1.724131
# 2016-06-30  新疆生产建设兵团第六师国有资产经营有限责任公司 -1.261334   0.745595 -1.140379
# 2016-12-31  新疆生产建设兵团第六师国有资产经营有限责任公司 -0.833186  -1.630456 -0.712209
# 2017-03-31  新疆生产建设兵团第六师国有资产经营有限责任公司 -1.221802  -1.735538 -1.250023
# 2017-06-30  新疆生产建设兵团第六师国有资产经营有限责任公司 -1.053352  -1.820156 -1.170228
# 2017-09-30  新疆生产建设兵团第六师国有资产经营有限责任公司 -0.653031  -0.939512 -0.974024
# 2018-03-31  新疆生产建设兵团第六师国有资产经营有限责任公司 -1.345240  -2.430510 -1.427194
#
#             筹资活动现金流(亿元)  主营业务利润率(%)  主营业务收入增长率(%)  投资活动现金流(亿元)  净资产回报率(%)  \
# 报告期
# 2016-03-31     0.842136   -1.322245      6.391666     2.110962  -4.098005
# 2016-06-30    -0.911901   -7.320250     -3.102262     2.080562   0.410571
# 2016-12-31    -1.891611   -1.396979     -2.214950     1.097175  -1.209295
# 2017-03-31     0.266761   -1.161610      1.013630     0.907222  -1.587410
# 2017-06-30    -0.783732   -0.991694      1.219125     0.511116  -1.501856
# 2017-09-30     1.149206   -0.530799      0.375040     0.438609  -1.412630
# 2018-03-31    -0.823264   -2.182058      0.752173     0.277939  -1.787180
#
#             总资产报酬率(%)      流动比率  经营活动现金流(亿元)
# 报告期
# 2016-03-31  -1.208708  0.962192    -2.916603
# 2016-06-30  -1.330516  2.003252    -2.543357
# 2016-12-31  -0.126586  1.033949    -2.559672
# 2017-03-31  -1.781123  0.862620    -2.346397
# 2017-06-30  -1.848131  1.292461    -0.702139
# 2017-09-30  -1.804707  2.054206    -2.212696
# 2018-03-31  -2.001986  1.390630     0.313063

# %%
a = [('获息倍数', 0.10293085778684695),('货币资金/短期债务', 0.08466747934544402),('净利润(亿元)', 0.08119844386846073),
     ('筹资活动现金流(亿元)', 0.07392047950839306),('主营业务利润率(%)', 0.07373536447871205),('主营业务收入增长率(%)', 0.0681957815907612),
 ('货币资金/总债务', 0.059822816991053754),('投资活动现金流(亿元)', 0.056517651957992715),('净资产回报率(%)', 0.05488686308572023),
 ('总资产报酬率(%)', 0.036039995560997476),('短期债务/总债务', 0.0350832996152875),('EBITDA/营业总收入', 0.034048366402690815),
 ('经营活动现金流(亿元)', 0.0243060183484769),('EBITDA/带息债务', 0.023188518342373905),('流动比率', 0.020910667354810814),
 ('成立日期', 0.0202111066498566),('经营性现金流/EBITDA', 0.019427371835625647),('货币资产(亿元)', 0.018929246296673925),
 ('净债务(亿元)', 0.015673135947545064),('EBITDA(亿元)', 0.013656585077388917),('带息债务/总投入资本', 0.013195889611687595),('主营业务利润(亿元)', 0.012345481772175503),
 ('总资产(亿元)', 0.01071488982344452),('净资产(亿元)', 0.009601482353160072),('总债务(亿元)', 0.009112083719364693),
 ('主营业务收入(亿元)', 0.006851438201812423),('速动比率', 0.005393658415696681),('存货周转率', 0.00521645305170003),
 ('资产负债率', 0.0034618581489861853),('带息债务(亿元)', 0.002858337636445684),('是否上市_否', 0.002687756282129772),
 ('企业性质_民营企业', 0.0012106209382845353),('注册资金低', 0.0),('注册资金中等', 0.0),
 ('注册资金高', 0.0),('企业性质_中外合资企业', 0.0),('企业性质_中央国有企业', 0.0),('企业性质_地方国有企业', 0.0),
 ('企业性质_外商独资企业', 0.0),('企业性质_外资企业', 0.0),('企业性质_集体企业', 0.0),('是否上市_是', 0.0)]
a = dict(a)
a = [a[i] for i in outdata.columns[1:]]
a = [j/sum(a) for j in a]
outdata['加权平均'] = outdata.iloc[:,1:].values.dot(np.array(a).reshape(-1,1))

# %%
z = pd.read_excel(path+'2017a.xlsx')

# %%
z = z[list(z.columns[:2])+list_+['经营活动现金流(亿元)']]

# %%
z = z.loc[z['名称']=='新疆生产建设兵团第六师国有资产经营有限责任公司',:]

# %%
z = z.iloc[0,:]

# %%
z.fillna(1.3,inplace=True)

# %%
z
# Out:
# 名称              新疆生产建设兵团第六师国有资产经营有限责任公司
# 报告期                 2017-12-31 00:00:00
# 获息倍数                                1.3
# 货币资金/短期债务                     0.0820865
# 净利润(亿元)                        -3.50252
# 筹资活动现金流(亿元)                     11.2072
# 主营业务利润率(%)                      -8.3078
# 主营业务收入增长率(%)                    14.6426
# 投资活动现金流(亿元)                  -0.0295982
# 净资产回报率(%)                        0.2535
# 总资产报酬率(%)                       -1.1393
# 流动比率                             2.1238
# 经营活动现金流(亿元)                    -15.1898
# Name: 3937, dtype: object

# %%
z = pd.DataFrame(z).stack().unstack(0).set_index('报告期',)

# %%
weight = joblib.load(path+'weight_dict_a.m')

# %%
for i in range(z.shape[1]-1):
    z.iloc[:,i+1] =(z.iloc[:,i+1]-weight[z.columns[i+1]][0])/weight[z.columns[i+1]][1]

# %%
z
# Out:
#                                  名称    获息倍数 货币资金/短期债务  净利润(亿元) 筹资活动现金流(亿元)  \
# 报告期
# 2017-12-31  新疆生产建设兵团第六师国有资产经营有限责任公司 -1.1993  -2.42139 -22.5031     1.45793
#
#            主营业务利润率(%) 主营业务收入增长率(%) 投资活动现金流(亿元) 净资产回报率(%) 总资产报酬率(%)     流动比率  \
# 报告期
# 2017-12-31   -3.34059     0.493806     1.10189  -1.43402  -3.18212  1.50703
#
#            经营活动现金流(亿元)
# 报告期
# 2017-12-31    -6.27212

# %%
outdata
# Out:
#                                  名称      获息倍数  货币资金/短期债务   净利润(亿元)  \
# 报告期
# 2016-03-31  新疆生产建设兵团第六师国有资产经营有限责任公司 -1.450960   0.735140 -1.724131
# 2016-06-30  新疆生产建设兵团第六师国有资产经营有限责任公司 -1.261334   0.745595 -1.140379
# 2016-12-31  新疆生产建设兵团第六师国有资产经营有限责任公司 -0.833186  -1.630456 -0.712209
# 2017-03-31  新疆生产建设兵团第六师国有资产经营有限责任公司 -1.221802  -1.735538 -1.250023
# 2017-06-30  新疆生产建设兵团第六师国有资产经营有限责任公司 -1.053352  -1.820156 -1.170228
# 2017-09-30  新疆生产建设兵团第六师国有资产经营有限责任公司 -0.653031  -0.939512 -0.974024
# 2018-03-31  新疆生产建设兵团第六师国有资产经营有限责任公司 -1.345240  -2.430510 -1.427194
#
#             筹资活动现金流(亿元)  主营业务利润率(%)  主营业务收入增长率(%)  投资活动现金流(亿元)  净资产回报率(%)  \
# 报告期
# 2016-03-31     0.842136   -1.322245      6.391666     2.110962  -4.098005
# 2016-06-30    -0.911901   -7.320250     -3.102262     2.080562   0.410571
# 2016-12-31    -1.891611   -1.396979     -2.214950     1.097175  -1.209295
# 2017-03-31     0.266761   -1.161610      1.013630     0.907222  -1.587410
# 2017-06-30    -0.783732   -0.991694      1.219125     0.511116  -1.501856
# 2017-09-30     1.149206   -0.530799      0.375040     0.438609  -1.412630
# 2018-03-31    -0.823264   -2.182058      0.752173     0.277939  -1.787180
#
#             总资产报酬率(%)      流动比率  经营活动现金流(亿元)      加权平均
# 报告期
# 2016-03-31  -1.208708  0.962192    -2.916603 -0.039001
# 2016-06-30  -1.330516  2.003252    -2.543357 -1.337332
# 2016-12-31  -0.126586  1.033949    -2.559672 -1.070478
# 2017-03-31  -1.781123  0.862620    -2.346397 -0.753055
# 2017-06-30  -1.848131  1.292461    -0.702139 -0.761336
# 2017-09-30  -1.804707  2.054206    -2.212696 -0.417947
# 2018-03-31  -2.001986  1.390630     0.313063 -1.105021

# %%
z['加权平均'] = z.iloc[:,1:].values.dot(np.array(a).reshape(-1,1))

# %%
z = pd.concat([outdata,z])[outdata.columns]

# %%
outdata = z.sort_index()

# %%
for i in range(outdata.shape[1]-1):
    ax = plt.subplot(4,3,i+1)
    outdata.iloc[:,i+1].plot(label=outdata.columns[i+1],)
    ax.legend(loc='best',prop={'size':11})
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.set_xlabel('')
plt.suptitle('新疆生产建设兵团第六师国有资产经营有限责任公司')
plt.show()

# %% [markdown]
# # 画图

# %% [markdown]
# ## -------------

# %%
data_object['result'] = a.predict(data_2018)

# %%
data_object[data_object['result']==1].shape

# %%
a = dict(a)
a = [j for j in a.values()][:10]+[a['经营活动现金流(亿元)']]
a = [j/sum(a) for j in a]

# %%
def pct_ch(dataframe):
    for i in range(dataframe.shape[1]):
        name = dataframe.columns[i]+'_rate'
        dataframe[name] = pd.Series()
        for j in range(dataframe.shape[0]-1):
            dataframe.iloc[j+1,-1] = (dataframe.iloc[j+1,i]-dataframe.iloc[j,i])/abs(dataframe.iloc[j,i])
    return dataframe.iloc[1:,:]

b_median = b_.iloc[:,1:].groupby('报告期').median().iloc[::-1,:]
b_median['加权平均'] = b_median.values.dot(np.array(a).reshape(-1,1))
b_median = pct_ch(b_median)
b_median.index = [i for i in range(-b_median.shape[0]+1,0+1)]

b_mean = b_.iloc[:,1:].groupby('报告期').mean().iloc[::-1,:]
b_mean['加权平均'] = b_mean.values.dot(np.array(a).reshape(-1,1))
b_mean = pct_ch(b_mean)
b_mean.index = [i for i in range(-b_mean.shape[0]+1,0+1)]

lenght = int(prepared_frame.shape[1]/2)

prepared_frame = b_median
plt.figure()
for i in range(lenght):
    ax = plt.subplot(4,3,i+1)
    prepared_frame.iloc[:,i].plot(label=prepared_frame.columns[i+lenght],)
    ax.legend(loc='best',prop={'size':11})
    for X,Y,Z in zip(prepared_frame.index,prepared_frame.iloc[:,i],prepared_frame.iloc[:,i+lenght]):
        plt.text(X,Y,'%.2f'%Z,ha='center',va='bottom')
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    if i == 1:
        plt.title('趋势变化图(中位数)',fontdict={'size':20})
plt.show()

prepared_frame = b_mean
plt.figure()
for i in range(lenght):
    ax = plt.subplot(4,3,i+1)
    prepared_frame.iloc[:,i].plot(label=prepared_frame.columns[i],)
    ax.legend(loc='best',prop={'size':11})
    for X,Y,Z in zip(prepared_frame.index,prepared_frame.iloc[:,i],prepared_frame.iloc[:,i+lenght]):
        plt.text(X,Y,'%.2f'%Z,ha='center',va='bottom')
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    if i == 1:
        plt.title('趋势变化图(平均数)',fontdict={'size':20})
plt.show()

# %%
b_median.to_excel(path+'median_.xlsx',index=False)
b_mean.to_excel(path+'mean_.xlsx',index=False)

# %%
re_of_de = pd.read_excel(path+'report of defaulted.xlsx',)[:-2]

# %%
pd.DataFrame(re_of_de['发生日期'].groupby(re_of_de['名称'],).apply(lambda x:x.sort_values('发生日期').iloc[0]))

# %%
pd.concat([pd.concat([re_object_0,re_of_de_0],axis=1),pd.concat([re_object_1,re_of_de_1],axis=1)]).drop_duplicates(['名称'])['企业性质_中央国有企业'].sum()
# Out:
# 4
